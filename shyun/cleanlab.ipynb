# %% [markdown]
# ### logits 확인

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

tokenizer = AutoTokenizer.from_pretrained('../../model_v1.2.2')
model = AutoModelForSequenceClassification.from_pretrained('../../model_v1.2.2/checkpoint-144', num_labels=7).to(DEVICE) # v1.2.1로 학습한 모델

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

train = pd.read_csv('../../v1.2.2/train.csv')

model.eval()
preds = []
for _, data in tqdm(train.iterrows(), total=len(train)):
    tokenized = tokenizer(data['text'], padding='max_length', max_length=50, truncation=True, return_tensors='pt').to(DEVICE)
    with torch.no_grad():
        logits = model(**tokenized).logits.cpu().numpy()
        softmax = [np.exp(x)/np.sum(np.exp(logits)) for x in logits]
        preds.append({'ID': data['ID'], 'softmax': softmax})

preds[0]
# Out:
#   0%|          | 0/3250 [00:00<?, ?it/s]
# {'ID': 'ynat-v1_train_00003',
#  'softmax': [array([0.06120225, 0.17026156, 0.05120712, 0.04558142, 0.3258167 ,
#          0.30573836, 0.04019262], dtype=float32)]}

# %%
from cleanlab.filter import find_label_issues

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

pred_probs = [np.array(p['softmax'][0]) for p in preds]
pred_probs = np.array(pred_probs)

ordered_label_issues = find_label_issues(
    labels=train['target'],
    pred_probs=pred_probs,
    return_indices_ranked_by='self_confidence'
)

# %%
print(f"total {len(ordered_label_issues)}")
for issue in ordered_label_issues:
    print('input text:', train.iloc[issue]['text'])
    print('label:', train.iloc[issue]['target'])
    pred = np.argmax(pred_probs[issue])
    print('pred:', pred)
    train.loc[train['text']==train.iloc[issue]['text'], 'target'] = pred

    print('----------------------------------------')
# Out:
# total 466
# input text: 메시·호날두 UEFA 올해의 팀에 선정…EPL 선수 제로
# label: 5
# pred: 1
# ----------------------------------------
# input text: 스피드 P7zO 호tel에 W240 코르국 사자 K전환
# label: 5
# pred: 1
# ----------------------------------------
# input text: 호날두 vs 메시 266번째 엘클라시코가 온다
# label: 5
# pred: 1
# ----------------------------------------
# input text: 기성용정우영 없는 중원 구자철황인범 라인 뜰까
# label: 3
# pred: 1
# ----------------------------------------
# input text: MLB.com 다저스 3년 연속 WS 유력하지만 우승은 글쎄…
# label: 4
# pred: 1
# ----------------------------------------
# input text: WNBA 박지수 LA 스파크스 상대로 2득점 2리바운드
# label: 4
# pred: 1
# ----------------------------------------
# input text: 여자7위혁신k 출75M박 r발 작용한I
# label: 2
# pred: 1
# ----------------------------------------
# input text: 홈런 2방에 벌랜더 와르르…MLB 양키스 ALCS서 기사회생
# label: 0
# pred: 1
# ----------------------------------------
# input text: 칠레 청년 사자 우리서 자살 기도…구조과정서 사자 2마리 사살
# label: 5
# pred: 6
# ----------------------------------------
# input text: 누워서 타는 자전거로 평창동계올림픽 홍보
# label: 5
# pred: 1
# ----------------------------------------
# input text: 매x ZK실E1 0뤄지는U서울에 M의 8래를 봤다
# label: 3
# pred: 1
# ----------------------------------------
# input text: 삼성증권 1분기 영업이익 1천496억원…17% 감소
# label: 6
# pred: 5
# ----------------------------------------
# input text: 국고채 금리 일제히 하락…3년물 연 2.256%
# label: 0
# pred: 5
# ----------------------------------------
# input text: 게시판 AWS 22일 머신러닝 온라인 콘퍼런스
# label: 2
# pred: 4
# ----------------------------------------
# input text: UEFA 챔스리그 4강 마드리드 더비 성사…레알 vs 아...
# label: 0
# pred: 1
# ----------------------------------------
# input text: 후랭코프 5승 두산 20승 선착…SK·LG 맹추격
# label: 2
# pred: 1
# ----------------------------------------
# input text: 리그 발전 논의하는 KBO 윈터미팅 29∼30일 개최
# label: 6
# pred: 1
# ----------------------------------------
# input text: 일자 7실업률 4e일후 저준
# label: 6
# pred: 5
# ----------------------------------------
# input text: 시리보다 내가 낫다…빅스비의 세로드립 도발종합
# label: 2
# pred: 4
# ----------------------------------------
# input text: 인크루트 로봇직원 알리사 채용…사번은 24365
# label: 2
# pred: 4
# ----------------------------------------
# input text: 탱크·전투 헬기가 바닷속에…요르단 수중 군사 박물관 공개
# label: 5
# pred: 6
# ----------------------------------------
# input text: 일본  출6이u아 15일 n국…22일 고베 입단식
# label: 6
# pred: 1
# ----------------------------------------
# input text: LG G7 씽z 디플레이 M LCDx표기고 적q성 논n
# label: 3
# pred: 4
# ----------------------------------------
# input text: 최지만 3타수 무안타…타율 0.257
# label: 4
# pred: 1
# ----------------------------------------
# input text: 北 대남테러 예상유형은…사이버 공격·요인 테러 가능성
# label: 5
# pred: 6
# ----------------------------------------
# input text: 시판 S콤 5GX 부게크에2 7uK s
# label: 0
# pred: 4
# ----------------------------------------
# input text: 북극 북t퍼스트레이HLV주T9개V에 공 UI
# label: 2
# pred: 6
# ----------------------------------------
# input text: 여자농구 KB국민은행 2018-2019 시즌권 11일부터 판매
# label: 4
# pred: 1
# ----------------------------------------
# input text: UEFA 파리 생제르맹 FFP 위반 여부 조사 착수
# label: 0
# pred: 1
# ----------------------------------------
# input text: 무례 외고노 일e무 교체ew부상4아베 11Uip
# label: 6
# pred: 1
# ----------------------------------------
# input text: SKT유콘시스템 5G 드론용 ICT 솔루션 개발 협력
# label: 0
# pred: 4
# ----------------------------------------
# input text: 국제유가·곡물가↓…올해 농업경영비 3.3% 감소 전망
# label: 4
# pred: 5
# ----------------------------------------
# input text: IoT로 쓰레기통 관리해요
# label: 2
# pred: 4
# ----------------------------------------
# input text: MLB닷컴 판타지 랭킹 추신수 176위류현진 188위 강정
# label: 0
# pred: 1
# ----------------------------------------
# input text: 中공안 장쑤 화학공단 폭발참사 책임자들 구금
# label: 2
# pred: 6
# ----------------------------------------
# input text: GS칼텍스 IBK기업은행과 세터 이나연↔이고은 트레이드
# label: 5
# pred: 1
# ----------------------------------------
# input text: 민=硏 보7- 논란j지속…野v매국적 정국\전략=집중포화
# label: 6
# pred: 2
# ----------------------------------------
# input text: 최지만 2경기 연속 안타…타율 0.269
# label: 0
# pred: 1
# ----------------------------------------
# input text: LG전자 스마트폰사업 10분기 적자…3Q 영업손실 3천753억종합
# label: 3
# pred: 5
# ----------------------------------------
# input text: LGU 조사거부 개별 안건으로…방통위 첫 단독 처리종합
# label: 6
# pred: 5
# ----------------------------------------
# input text: 현tuK수 김천웅 한국인h최초로 k스라I E체바무용단 입단
# label: 0
# pred: 1
# ----------------------------------------
# input text: 1930년대 재즈클럽으로 변한 공연장
# label: 5
# pred: 0
# ----------------------------------------
# input text: 클린턴 외교책사 북핵 6자회담 재개 신중해야 u3000
# label: 3
# pred: 6
# ----------------------------------------
# input text: 코리아^레길 민간추진협의회 2<일 출u식
# label: 1
# pred: 0
# ----------------------------------------
# input text: 코오롱플라스틱 1분기 연결 영업익 58억원…138%↑
# label: 6
# pred: 5
# ----------------------------------------
# input text: 국제선수권기구 FIVB 2026년 세계선수권대회 한국서 개최
# label: 5
# pred: 1
# ----------------------------------------
# input text: 팀 쿡 애플 CEO iOS 11 배포 통해 증강현실 본격화
# label: 0
# pred: 4
# ----------------------------------------
# input text: 현대차 현대차증권 MMT 300억원 매수
# label: 2
# pred: 5
# ----------------------------------------
# input text: 美 오만해 유조선공격 배후 이란 지목…이란 파병하려 날조
# label: 2
# pred: 6
# ----------------------------------------
# input text: 우리은행 박혜진 연봉 3억원으로 2년 연속 연봉 퀸
# label: 5
# pred: 1
# ----------------------------------------
# input text: 북한c조선}?TV 잠시 } 특별 중6방송 예고
# label: 5
# pred: 6
# ----------------------------------------
# input text: IC 카드단말기 미전환시 21일부터 결제 차단
# label: 6
# pred: 5
# ----------------------------------------
# input text: 메리츠종금 내년 코스피 1900-24,000 등락
# label: 1
# pred: 5
# ----------------------------------------
# input text: 현대차 8월 국내 판매 전년비 17.6%↓
# label: 0
# pred: 5
# ----------------------------------------
# input text: 게시판 KT 정보보안 기업 4곳과 MOU
# label: 1
# pred: 4
# ----------------------------------------
# input text: 타후의5J9지c 이라엘 야권연대9성사SD
# label: 6
# pred: 2
# ----------------------------------------
# input text: 밀린 통신비 신용등급 반영한 SKT…즉시 중단종합2보
# label: 1
# pred: 5
# ----------------------------------------
# input text: LG전자 트리플 카메라 장착한 LG X6 출시
# label: 0
# pred: 4
# ----------------------------------------
# input text: C\이?X 美47 Q작 기후위M `<…>켓 j수는 실패
# label: 4
# pred: 6
# ----------------------------------------
# input text: 트럼프 中 거래 원해도 美 준비 안돼…이란 체제전환 요구안해
# label: 5
# pred: 6
# ----------------------------------------
# input text: 신간 삶이라는 동물원·지방도시 살생부
# label: 5
# pred: 0
# ----------------------------------------
# input text: LG G8 씽큐 15일부터 예판…디스플레이 1회 무상교체 혜택
# label: 2
# pred: 4
# ----------------------------------------
# input text: KT 1만원대 LTE 요금제와 함께 피처폰 LG 폴더 출시
# label: 2
# pred: 4
# ----------------------------------------
# input text: 교양만화로 돌아온 윤태호 지적호기심 강한 시대에 맞는 만화
# label: 1
# pred: 0
# ----------------------------------------
# input text: h신당 *#호)친노 지역구에l특별)천…전면전 선포
# label: 6
# pred: 2
# ----------------------------------------
# input text: 한투증권 빙그레 폭염에 빙과 수요 증가…매수
# label: 1
# pred: 5
# ----------------------------------------
# input text: 美 매d g츠버그 강정호와 y별p T
# label: 6
# pred: 1
# ----------------------------------------
# input text: 1보 코스피 상승 출발…장중 1.900선 돌파
# label: 0
# pred: 5
# ----------------------------------------
# input text: KT카스 NBIoT 사업협력을 위한 업무협약
# label: 6
# pred: 4
# ----------------------------------------
# input text: KT·SKT 나란히 국제표준 생체인증 획득종합
# label: 1
# pred: 4
# ----------------------------------------
# input text: 아시안게임 응원석엔 하나된 함성 벤치엔 우정의 미소…...
# label: 0
# pred: 1
# ----------------------------------------
# input text: 게시판 수요낭독공감 8일·22일 개최
# label: 5
# pred: 0
# ----------------------------------------
# input text: 다음달 4∼7일 첫 민화전문 아트페어 열린다
# label: 5
# pred: 0
# ----------------------------------------
# input text: 대선출마 앞둔 바이든의 나쁜손 또 폭로…코 비비려고 했다
# label: 5
# pred: 2
# ----------------------------------------
# input text: SKT AI 콘퍼런스 aix 2019 개최
# label: 6
# pred: 4
# ----------------------------------------
# input text: 이란 인공위성 발사체 폭발 사고 자인…기술 결함
# label: 5
# pred: 6
# ----------------------------------------
# input text: 오바마 폭력범죄ㆍ불법이민 증가 트럼프 주장 반박
# label: 5
# pred: 6
# ----------------------------------------
# input text: o국 초등학교 3부% 투Y 교육 시킨-
# label: 6
# pred: 0
# ----------------------------------------
# input text: 평t 폭주tP당 $제 위d 민생L당 평화 지지해달라
# label: 0
# pred: 2
# ----------------------------------------
# input text: SKT 부산 엑스포서 해양안전 통신기술 시연
# label: 1
# pred: 4
# ----------------------------------------
# input text: LHEVK0로 촬영 단편4화6편 뉴욕 필름 페스벌이 화제
# label: 4
# pred: 0
# ----------------------------------------
# input text: $민'커진 :남원jw독8e%프 원래 설렁설렁"다
# label: 1
# pred: 2
# ----------------------------------------
# input text: 2·(\독립$@ 100주년…도쿄·서u서 기념식 거행종합W보
# label: 3
# pred: 6
# ----------------------------------------
# input text: 미래부OECD 과학기술정책위원회 워크숍 개최
# label: 6
# pred: 4
# ----------------------------------------
# input text: 黃 단식중단w도 패스트$랙|대치 @속…靑감찰의혹 공L 가열
# label: 3
# pred: 2
# ----------------------------------------
# input text: HDC 부동산114 자회사로 편입
# label: 6
# pred: 5
# ----------------------------------------
# input text: 기사2지수 1.3% 상승…유가 하락로 전환
# label: 3
# pred: 5
# ----------------------------------------
# input text: 정정불안 코모로서 총격 사상자 발생…美 정부요원 철수명령
# label: 2
# pred: 6
# ----------------------------------------
# input text: 주유소 기름값 계속 오르는데…국제유가 더 상승할까
# label: 4
# pred: 5
# ----------------------------------------
# input text: 5G 상용화 100일간 이통3사 시가총액 희비
# label: 2
# pred: 4
# ----------------------------------------
# input text: 국제유가 사흘만에 반등…WTI 이번주 2.2%↓
# label: 2
# pred: 5
# ----------------------------------------
# input text: 출연연 국내출장비 정산 실비정산→정액지급…증빙수단 간소화
# label: 2
# pred: 5
# ----------------------------------------
# input text: 디딤. 대;에도g모-#신> !Om*
# label: 5
# pred: 0
# ----------------------------------------
# input text: 전화번호로 NCSu삼9페 카스간 7Wnzd스
# label: 4
# pred: 1
# ----------------------------------------
# input text: KRs리우올림픽 홀로그램6응7 ~= '작
# label: 4
# pred: 1
# ----------------------------------------
# input text: 삼성 갤노트10 70개국 출시 9월 130개국으로 확대
# label: 3
# pred: 4
# ----------------------------------------
# input text: SKT 갤럭시 A8 스타 단독 출시
# label: 3
# pred: 4
# ----------------------------------------
# input text: 본국 애스턴마틴 Sp라 국내 4P500대g 생산
# label: 0
# pred: 5
# ----------------------------------------
# input text: 北|마라톤 선수단 올림hz참가 자격위Om?B행위
# label: 2
# pred: 1
# ----------------------------------------
# input text: 日언론 고노 외상 美 USTR 대표와 회담…WTO 개혁 연대키로
# label: 5
# pred: 6
# ----------------------------------------
# input text: 靑 대단히 중요한 순방…丁의장 사드 발언 우려
# label: 5
# pred: 2
# ----------------------------------------
# input text: 네이버 아이n 도용 방지26&화
# label: 0
# pred: 4
# ----------------------------------------
# input text: 13이 노바 라이n2미J어패0 T3 10 결G상품
# label: 6
# pred: 4
# ----------------------------------------
# input text: 폭염엔 역시 얼음
# label: 3
# pred: 0
# ----------------------------------------
# input text: 與내부 핵무장론 탄력…사드 배치도 다시 공론화
# label: 3
# pred: 2
# ----------------------------------------
# input text: 네이버 모바일 첫 화면 검색창 위주 개편…뉴스·실급검 뺀다종합
# label: 6
# pred: 4
# ----------------------------------------
# input text: 네이버 상징 녹색창에서 그린닷으로…모든 서비스 시작점종합2보
# label: 1
# pred: 4
# ----------------------------------------
# input text: 만지고 쓰다듬는 일은 왜 중요한가…터칭의 세계
# label: 1
# pred: 0
# ----------------------------------------
# input text: 이녹스 1분기 영업이익 17억원…76% 감소
# label: 3
# pred: 5
# ----------------------------------------
# input text: KT 기가지니 더 똑똑해진다…가입자도 30만 돌파 쑥쑥
# label: 1
# pred: 4
# ----------------------------------------
# input text: SK텔레콤 트리페이 태국 서비스 개시
# label: 6
# pred: 4
# ----------------------------------------
# input text: 추미애 검언유착 책임론 정면돌파…윤석열 고립·이성윤 신임종합
# label: 5
# pred: 2
# ----------------------------------------
# input text: 네이3미 유11인지Nj2회A문2편j호평
# label: 4
# pred: 0
# ----------------------------------------
# input text: 패스트트랙 수사 검찰 국회 운영위 등 압색
# label: 1
# pred: 2
# ----------------------------------------
# input text: 미국발 훈풍 코스피 장중 2120선 회복…코스닥 2% 올라종합2보
# label: 4
# pred: 5
# ----------------------------------------
# input text: 윤KCA감w장 베h남nL앙T1서 tfA세미나 발표
# label: 5
# pred: 0
# ----------------------------------------
# input text: r사말하는 미즈타니7사장
# label: 6
# pred: 0
# ----------------------------------------
# input text: 네덜란드 정부 보스니아 무슬림 학살사건에 10% 책임
# label: 2
# pred: 6
# ----------------------------------------
# input text: 충북 말복 더위 지속…강한 소나기 주의
# label: 3
# pred: 0
# ----------------------------------------
# input text: SK텔레콤 충청 지역 폭우피해 통신망 복구
# label: 1
# pred: 4
# ----------------------------------------
# input text: 프랑스 공무원 대규모 감축목표서 후퇴…감원폭 줄이기로
# label: 2
# pred: 6
# ----------------------------------------
# input text: 이1서 h국 강조~%민=C 캐}다서^P정T_U의혹 3[ 비판
# label: 6
# pred: 2
# ----------------------------------------
# input text: 수묵 큰 잔치 첫 국제수묵비엔날레 9월 개막
# label: 6
# pred: 0
# ----------------------------------------
# input text: 섬들의 근대화는 달랐다…일제가 쓰고 버린 태평양 섬 이야기
# label: 1
# pred: 0
# ----------------------------------------
# input text: 한·\·일I몽골 전문_r미세먼[ 해( 위해 at았다
# label: 3
# pred: 6
# ----------------------------------------
# input text: 코스피 미국발 악재에 또 급락…2360대로 털썩
# label: 4
# pred: 5
# ----------------------------------------
# input text: KB증권 2분기 영업익 1천5억원221 증가
# label: 4
# pred: 5
# ----------------------------------------
# input text: 그래픽 제조업 평균 가p률#p이
# label: 4
# pred: 5
# ----------------------------------------
# input text: 정몽구 현대건설 이사직 물러나…자동차에 주력
# label: 4
# pred: 5
# ----------------------------------------
# input text: 레바논서 사흘째 거리시위…경제난에 정권퇴진 요구
# label: 2
# pred: 6
# ----------------------------------------
# input text: 제4기 여론집중도조사위 출범…위원장에 김영욱 교수
# label: 1
# pred: 2
# ----------------------------------------
# input text: 전세보증금 반환보증 가입 급증…전세금 받아달라 청구도↑종합
# label: 0
# pred: 5
# ----------------------------------------
# input text: 위민크로스DMZ 28일 남북 평화기원 걷기행사
# label: 1
# pred: 0
# ----------------------------------------
# input text: +라'~r리{밟은o밍스~A경4?[전정지 중징계
# label: 6
# pred: 1
# ----------------------------------------
# input text: 베스트셀러 김난도 트렌드 코리아 2020 3주째 1위
# label: 3
# pred: 0
# ----------------------------------------
# input text: 11월 주식 발행액 전월비 60% 증가…IPO·유상증자↑
# label: 4
# pred: 5
# ----------------------------------------
# input text: 온종일 차는 스s트!치 전자파i얼마나 나vh
# label: 4
# pred: 0
# ----------------------------------------
# input text: LGU 잠실야구장에 프로야구 5G 체험존 운영
# label: 3
# pred: 1
# ----------------------------------------
# input text: 국회 대선비리 수사로 5명 체포
# label: 3
# pred: 2
# ----------------------------------------
# input text: 버닝썬 게이트 다룬 SBS 그것이 알고 싶다 11.2％
# label: 6
# pred: 2
# ----------------------------------------
# input text: 이공대 내부 살펴보는 홍콩 경찰
# label: 1
# pred: 6
# ----------------------------------------
# input text: 朴대통령 시릴만큼 아프게 부모잃어…안보소명론으로 사드호소종합
# label: 0
# pred: 2
# ----------------------------------------
# input text: 대우선해양 4천199억원bxC LNG 운선 2척n수주
# label: 3
# pred: 5
# ----------------------------------------
# input text: KAIST 온도따라 변하는 스마트 입자 개발
# label: 0
# pred: 4
# ----------------------------------------
# input text: 코스피 외국인·개인 팔자에 하락…사흘만에 2200 밑으로종합
# label: 4
# pred: 5
# ----------------------------------------
# input text: 북한도 Yr스료개 s공단 출p원 m발열 W사 RXj종합
# label: 2
# pred: 6
# ----------------------------------------
# input text: 아트O V4c미i m9
# label: 4
# pred: 0
# ----------------------------------------
# input text: 비자나무는 모기퇴치제…옛 문헌 속 생물활용서 발간
# label: 3
# pred: 0
# ----------------------------------------
# input text: 美외교관 부인 차사고로 아들잃은 英부모 가해자·美정부 소송
# label: 0
# pred: 6
# ----------------------------------------
# input text: 주말 N 여행 충청권 달콤한 포도에 견우·직녀의 사랑까지
# label: 1
# pred: 0
# ----------------------------------------
# input text: 사람 닮아가는 kf의Z손dL이t아 나무의e 조1I공
# label: 4
# pred: 0
# ----------------------------------------
# input text: MBC 류현진 특집 다큐…MLB 전설에게 듣는 류현진
# label: 0
# pred: 1
# ----------------------------------------
# input text: 네이버뮤직 바이브로 통합…기존 서비스 내년 종료
# label: 1
# pred: 4
# ----------------------------------------
# input text: 日도쿄 주택가 공원 연못서 토막시신 발견
# label: 1
# pred: 6
# ----------------------------------------
# input text: 게시판 KISA 박민정 책임연구원 APTLD 이사 선출
# label: 0
# pred: 4
# ----------------------------------------
# input text: 보수 논객 변희재 eXn속심사A블릿 조Q6 x포C혐
# label: 3
# pred: 2
# ----------------------------------------
# input text: 군부가 축출한 바시르 수단 전 대통령 교도소 수감
# label: 2
# pred: 6
# ----------------------------------------
# input text: 흥국운용 2천350억원 중순위 인수금융펀드 1호 결성 완료
# label: 4
# pred: 5
# ----------------------------------------
# input text: 자본 L y간 15년 우리의 5 ostr 떻F읽Y lR
# label: 0
# pred: 5
# ----------------------------------------
# input text: 아폴로13호 선장 LG V30로 47년만에 달 착륙 꿈 이뤘다
# label: 3
# pred: 4
# ----------------------------------------
# input text: LGk플q스이소상공인U위한 U장님키지 출시
# label: 3
# pred: 4
# ----------------------------------------
# input text: 중정u 지방W민0투Ad실태K6L착5
# label: 6
# pred: 2
# ----------------------------------------
# input text: 그래픽 작년 주식 1인당 보유종목수 4.27개
# label: 4
# pred: 5
# ----------------------------------------
# input text: 2보 코스피 상승 출발…개인 매수에 장중 1940선 회복
# label: 1
# pred: 5
# ----------------------------------------
# input text: SKT 미래 고객 잡는다
# label: 3
# pred: 4
# ----------------------------------------
# input text: 한투 정부 정책방향 소폭 전환…경기하강 방어에 긍정적
# label: 3
# pred: 5
# ----------------------------------------
# input text: a모쇼 벤츠스포 X카 성SF XHEV B셉트카 5개
# label: 0
# pred: 4
# ----------------------------------------
# input text: 추미애 朴정부 비리조차도 창조적…불공정 한국 끝 보는 듯
# label: 0
# pred: 2
# ----------------------------------------
# input text: 러 우주로켓 벼락 맞고도 멀쩡…탑재 위성 정상궤도 올려
# label: 5
# pred: 6
# ----------------------------------------
# input text: 보령소식 보령시 시간선택제 공무원 3명 모집
# label: 1
# pred: 3
# ----------------------------------------
# input text: 스카이스캐너 올해 설 연휴 가족 해외여행객 증가
# label: 6
# pred: 5
# ----------------------------------------
# input text: 갯벌도 얼려버린^한파
# label: 5
# pred: 0
# ----------------------------------------
# input text: 출마금cyj슈9웡 홍'!.t(!%원하면 투표해t
# label: 6
# pred: 2
# ----------------------------------------
# input text: 中 RCEP 추진 박차…아태지역 통합에 TPP보다 유리
# label: 0
# pred: 6
# ----------------------------------------
# input text: 120개 언어 인도 힌디어 국어 지정 놓고 찬반 논란
# label: 2
# pred: 6
# ----------------------------------------
# input text: 야구장 암표팔다 적발 기초수급자 타인 인적사항 도용
# label: 2
# pred: 3
# ----------------------------------------
# input text: 케냐 대통령 한국산 자동차 몰고 한국산 TV 매일 본다
# label: 0
# pred: 6
# ----------------------------------------
# input text: KTB투자 대림산업 2분기 호실적…목표주가↑
# label: 4
# pred: 5
# ----------------------------------------
# input text: 정끝별 시인이 말하는 패러디…이 시대 중심 표현방법
# label: 1
# pred: 0
# ----------------------------------------
# input text: 클린턴재단 후폭풍인가…힐러리 vs 트럼프 지지율 3%p로 좁혀져
# label: 0
# pred: 2
# ----------------------------------------
# input text: 광주전남 보도사진전 전남도청서 개막
# label: 6
# pred: 0
# ----------------------------------------
# input text: 조국U압수수색f검2와 통7 파장…한h·바(미래 &핵K진i
# label: 3
# pred: 2
# ----------------------------------------
# input text: 방통위 KBS 보궐이사에 강형철 숙명여대 교수 추천
# label: 0
# pred: 2
# ----------------------------------------
# input text: 네이버 야심작 웨일 써보니…화면 분할 기능 편리
# label: 1
# pred: 4
# ----------------------------------------
# input text: x진k탈출F롯P 노경은 박+웅과o경쟁 기대한9
# label: 1
# pred: 2
# ----------------------------------------
# input text: 1:)점 박철ey7Rf< 크게 O더니 온몸에 쥐났어요
# label: 1
# pred: 0
# ----------------------------------------
# input text: 홍n~거리청소 나선&부c T국 내 최m8대테6 np부대
# label: 6
# pred: 2
# ----------------------------------------
# input text: 아r널R벵거 감B Y?u 비\에 감u에 o~ ,볍다...
# label: 1
# pred: 0
# ----------------------------------------
# input text: 반으로 쪼개진 바른미래…두번 표결에 1표차 아슬아슬한 추인종합2보
# label: 1
# pred: 2
# ----------------------------------------
# input text: 민주 누리과정예산 확보 대신 법인세 양보 모색
# label: 5
# pred: 2
# ----------------------------------------
# input text: 톈궁 M호 9시16분Q남태v양 추락…과기부 위기l보 해제
# label: 3
# pred: 6
# ----------------------------------------
# input text: 남편의 과도한 사랑에 숨 막혀…UAE서 아내 이혼청구
# label: 5
# pred: 6
# ----------------------------------------
# input text: 온*으Q 한방 바Z_를 느끼다…|천~한방D스N D20
# label: 3
# pred: 0
# ----------------------------------------
# input text: 올림픽|N데월드몰 0니j컬링y경R s벤0 진행
# label: 0
# pred: 1
# ----------------------------------------
# input text: 문희상 의장 취임 기자간담회
# label: 0
# pred: 2
# ----------------------------------------
# input text: 대전시 내년 생'임[ .급 a만T>2원으로 `정
# label: 5
# pred: 3
# ----------------------------------------
# input text: 미국서 J B8 심 집지 V달 5Y 광조 K 위
# label: 4
# pred: 6
# ----------------------------------------
# input text: 새누리 원내대표 CL 화|는,여소야대·계파
# label: 1
# pred: 2
# ----------------------------------------
# input text: 獨 언론 극우 AfD 의원 러시아로부터 통제당해
# label: 2
# pred: 6
# ----------------------------------------
# input text: 아베 개헌논의 안 해도 좋은지 선거서 물을 것…개헌 이슈화
# label: 1
# pred: 2
# ----------------------------------------
# input text: 억만장자 베니 스타인메츠 阿 광산 뇌물 혐의로 기소돼
# label: 2
# pred: 6
# ----------------------------------------
# input text: o거래가 r장 }싼 역세권은 신반포역…3.%㎡> B억 육박
# label: 1
# pred: 5
# ----------------------------------------
# input text: 伊-대통Q6+ 연정 승인…콘테dz 총n에 `정1구성V권G 부여
# label: 6
# pred: 2
# ----------------------------------------
# input text: 트럼프가 한사코 부인했는데…멀베이니가 우크라 대가성 인정종합
# label: 0
# pred: 6
# ----------------------------------------
# input text: NEW트렌드 바람과 파도를 즐기는 또 다른 방법
# label: 1
# pred: 0
# ----------------------------------------
# input text: ktGV조국 r퇴kPM개L 향방은MBC 1p0N 토론
# label: 3
# pred: 5
# ----------------------------------------
# input text: LGU 5G SA 상용화 준비 SA 기술 NSA 코어 장비에 연동 검증
# label: 5
# pred: 4
# ----------------------------------------
# input text: 월미도 새 모노레일 내년 추석엔 달릴 수 있을까
# label: 6
# pred: 0
# ----------------------------------------
# input text: 인-]항 무n열cV화재 가정한:비}Hc
# label: 3
# pred: 4
# ----------------------------------------
# input text: 조코위 인니 대통령 휴대전화 없고 쓰지도 않는다
# label: 5
# pred: 6
# ----------------------------------------
# input text: 국제기구 대규모 자원봉사자 수용… 한국의 인도 인력 수출 가능성
# label: 3
# pred: 6
# ----------------------------------------
# input text: NHN엔터테인먼트 2분기 영업익 149억50원 증가
# label: 3
# pred: 5
# ----------------------------------------
# input text: 게시판 자랑스러운 한양언론인상에 임철순·이숙영
# label: 1
# pred: 0
# ----------------------------------------
# input text: 성 추#n만 가 박재동 피p7} _=_책E:겠n
# label: 3
# pred: 0
# ----------------------------------------
# input text: 작년 12월 전국 미분양 6만 1천여가구… 한달새 23.7%
# label: 0
# pred: 5
# ----------------------------------------
# input text: 25남2 광객nG버C N럭과 충돌01명 3상
# label: 6
# pred: 4
# ----------------------------------------
# input text: 지소미아 종료까지 8일…美 압박 속 고민 깊어지는 文대통령
# label: 0
# pred: 2
# ----------------------------------------
# input text: 黃 제1야당 대표로 첫 삭발 감행…조국 반대 대여투쟁 승부수종합2보
# label: 1
# pred: 2
# ----------------------------------------
# input text: 북한 혈전 AAR 전후 핵전쟁 올해 정전 Y전D
# label: 2
# pred: 6
# ----------------------------------------
# input text: 국회 정기회기 1주일 동안 상원 의원 1명 무기한 상정
# label: 3
# pred: 2
# ----------------------------------------
# input text: 아리 아라리 정선아리랑극 세계인에 선보인다
# label: 1
# pred: 0
# ----------------------------------------
# input text: LG화학 안k ,보 Q 된 사업은 안(한다…고강도F대책r발표
# label: 3
# pred: 5
# ----------------------------------------
# input text: 듀얼심 아이폰 하반기 출시설 솔솔…알뜰폰 기대감
# label: 1
# pred: 4
# ----------------------------------------
# input text: 삼성重도 올해 첫 수주…LNG선 2척 4천199억원 규모종합
# label: 1
# pred: 5
# ----------------------------------------
# input text: 스웨덴 여자축구대표팀 유니폼 문구로 여성인권 캠페인
# label: 0
# pred: 1
# ----------------------------------------
# input text: 미스터 _샤인 S프로 부^…인물들 납y해
# label: 1
# pred: 0
# ----------------------------------------
# input text: 천정배 내일 安과 담판…국민의당 野 연대갈등 중대기로
# label: 1
# pred: 2
# ----------------------------------------
# input text: LG전자 실속형 스마트폰 2018년형 K 시리즈 공개
# label: 1
# pred: 4
# ----------------------------------------
# input text: 北매체 로켓 발사 성공에 온나라 경축 분위기
# label: 1
# pred: 6
# ----------------------------------------
# input text: 신간 잘못 알려진 미니스커트 경제학
# label: 4
# pred: 0
# ----------------------------------------
# input text: 5기 방통위 정치 후견주의 극복하고 독립성 강화해야
# label: 5
# pred: 2
# ----------------------------------------
# input text: 쌍국 호주 동남아시아비즈니스ABiVz
# label: 5
# pred: 6
# ----------------------------------------
# input text: 美텍사스서 열기구 화재후 추락…최소 16명 사망한 듯종합
# label: 1
# pred: 6
# ----------------------------------------
# input text: 게시판 LGU 인천공항 로밍서비스 7회 연속 만족도 1위
# label: 1
# pred: 4
# ----------------------------------------
# input text: 리비아서 피랍 이탈리아 인질 극적 탈출로 목숨 건져
# label: 1
# pred: 6
# ----------------------------------------
# input text: 염#설 , 기업Ic존l 총리 j란 si r락 차단해
# label: 6
# pred: 2
# ----------------------------------------
# input text: '저자'와 '출판사' 간 불공평한 분쟁…문학계 분열
# label: 3
# pred: 0
# ----------------------------------------
# input text: 중국의 해외투자 안전도I평가서 Z국 O위→=_위t추락
# label: 6
# pred: 5
# ----------------------------------------
# input text: 김영란법 합헌 더민주 다행스러운 일…투명사회 노력 계속
# label: 0
# pred: 2
# ----------------------------------------
# input text: 오늘의 투자전략 美·中 정치환경 철강·기계에 모멘텀
# label: 4
# pred: 5
# ----------------------------------------
# input text: 국민의당 권은희 朴대통령 저격 풍자 SNS 포스터 논란
# label: 1
# pred: 2
# ----------------------------------------
# input text: it룽의 반지 국내 제작6초W…명랑한 바그너 입[
# label: 6
# pred: 0
# ----------------------------------------
# input text: 北조국통!민주X#전선 결성 <0돌 중;보고회 열x
# label: 0
# pred: 2
# ----------------------------------------
# input text: 5j픽R유료방4j점유+ 및 +편 후3전망
# label: 3
# pred: 4
# ----------------------------------------
# input text: 이해찬 대표 취임 축하 난 앞에 놓고 인사말
# label: 0
# pred: 2
# ----------------------------------------
# input text: CJ EM 플레디스엔터 지분 51% 인수 추진
# label: 3
# pred: 5
# ----------------------------------------
# input text: 외국인에게 말만 하세요 한컴 이어폰형 통역기 MWC서 첫선
# label: 6
# pred: 4
# ----------------------------------------
# input text: 금감원 이어 공정위까지…6부기관[사칭B악h메1 기승
# label: 3
# pred: 5
# ----------------------------------------
# input text: 애플 앱스토어에서 우버 앱 삭제될 뻔했다
# label: 1
# pred: 4
# ----------------------------------------
# input text: D인인증서 유출 Y LOO 넘어+추세는 급감
# label: 3
# pred: 5
# ----------------------------------------
# input text: 통신3사 5G 가입자 경쟁 불붙었다…LG V50 지원금 최대 77만원
# label: 1
# pred: 4
# ----------------------------------------
# input text: 한발 물러선 金 막지 않겠다…文 호남행 정면돌파
# label: 1
# pred: 2
# ----------------------------------------
# input text: 이통사 M{행] Z속D배상땐 조D·심의 중간& 종결
# label: 3
# pred: 5
# ----------------------------------------
# input text: 지주회사 해외사례 공부하는 공정위
# label: 4
# pred: 5
# ----------------------------------------
# input text: 트럼프 한국 등 방위비분담금 더 내라…양방향 도로 돼야
# label: 5
# pred: 6
# ----------------------------------------
# input text: 랜섬'어 국l 피해 신고 2건 추가t/ /4건
# label: 6
# pred: 4
# ----------------------------------------
# input text: 베어링운용 증시 기초여건 우호적…위험요건은 상존
# label: 4
# pred: 5
# ----------------------------------------
# input text: 홍남기 미래부 1차관 서울혁신센터 등 방문
# label: 0
# pred: 4
# ----------------------------------------
# input text: F C& 싱크탱 X노;}s브렉시트4&8 시간$방법!O족
# label: 6
# pred: 4
# ----------------------------------------
# input text: CJ헬로비전SKB 합병 무효 소송 잇따라…LGU＋ 법적 대응
# label: 3
# pred: 5
# ----------------------------------------
# input text: 보육시설 비리 근절을 위하여
# label: 0
# pred: 3
# ----------------------------------------
# input text: SNS3보}N김영z법 선물`}도 완화/ 찬반 격론
# label: 3
# pred: 2
# ----------------------------------------
# input text: 위클W 스Vr 전성시대 맞은 hTmM해외방c Y그램 l KO
# label: 0
# pred: 4
# ----------------------------------------
# input text: 삼성전자 주가 10% 오르면?
# label: 4
# pred: 5
# ----------------------------------------
# input text: 이채원 부사장 짧은 쇼크…주식 빨리 살 필요는 없다
# label: 4
# pred: 5
# ----------------------------------------
# input text: 의사훈t조J 미국 GW속y
# label: 2
# pred: 6
# ----------------------------------------
# input text: 총파업 코앞에 두고 국민은행 노사 막판협상…극적 타결될까종합
# label: 0
# pred: 5
# ----------------------------------------
# input text: 벼락같은 중거리포로 러시아 가는 길 열어젖힌 이창민종합
# label: 0
# pred: 1
# ----------------------------------------
# input text: 반기문m유p{e 관저에>리2창 부부 초대 만찬…2년전|약속지켜
# label: 0
# pred: 2
# ----------------------------------------
# input text: WSJ 스크린 5함 0란 갤Lb 폴드 조롱 동|상
# label: 4
# pred: 6
# ----------------------------------------
# input text: 노트르담 화재 이틀만에…휘발유 들고 美성당 침입한 남성 체포
# label: 1
# pred: 6
# ----------------------------------------
# input text: 게시판 KEB하나銀 내집마련 더블업 적금 가입자 2만명 돌파
# label: 4
# pred: 5
# ----------------------------------------
# input text: 사회정의를 분배 문제에 가두지 말라…지배와 억압 제거해야
# label: 0
# pred: 3
# ----------------------------------------
# input text: 이달의 편집상에 매일신문 공부까지 거리두면… 등 4편
# label: 2
# pred: 0
# ----------------------------------------
# input text: YTN사천T원회 7명p로늘려
# label: 3
# pred: 2
# ----------------------------------------
# input text: 오q지라이프{임원들 6사주y매각;보도는 사실무b
# label: 3
# pred: 5
# ----------------------------------------
# input text: 주Ia탄o 한국총영사관t한국 애니메이션의 Z 개u
# label: 6
# pred: 0
# ----------------------------------------
# input text: 美 미사일방어시스템 한국에 최대한 조기구축 희망1보
# label: 5
# pred: 6
# ----------------------------------------
# input text: 한국형 발사체 75t 엔진 첫 연소시험 성공
# label: 5
# pred: 4
# ----------------------------------------
# input text: p실군 섬진강댐 방문한@김u조77부a
# label: 3
# pred: 0
# ----------------------------------------
# input text: 빅스비 랩 해줘 명령에 노래하는 갤럭시S8종합
# label: 5
# pred: 4
# ----------------------------------------
# input text: 윤상현 오늘 아침 김무성 자택 찾아 사과했다속보
# label: 1
# pred: 2
# ----------------------------------------
# input text: 역사는 인간 어리석음의 기록…어리석은 선택의 반복 이유는
# label: 2
# pred: 0
# ----------------------------------------
# input text: 증시신상품 국채선물 인버스 ETF 3종
# label: 4
# pred: 5
# ----------------------------------------
# input text: 제주도 지자체 선거인구 감소로 인한 재정 부담 대책 필요
# label: 2
# pred: 3
# ----------------------------------------
# input text: 국`계Y%58 수립에 {공지능 기v2도입한다
# label: 4
# pred: 3
# ----------------------------------------
# input text: 프럼파스트 21억원어치 자사주 시간외 매매 결정
# label: 4
# pred: 5
# ----------------------------------------
# input text: 더민주 서영교 여파 지역위원장 심사기준 강화
# label: 3
# pred: 2
# ----------------------------------------
# input text: 美 지난주 실업수당청구건수 26만6천건…소폭 상승
# label: 3
# pred: 5
# ----------------------------------------
# input text: 불공정 혐의 단골 기업 공정위 본부 직접 조사받는다
# label: 2
# pred: 5
# ----------------------------------------
# input text: 한국MS 윈도10 IoT 에디션 출시 B2B 공략
# label: 5
# pred: 4
# ----------------------------------------
# input text: 독도로 출발하기 전 기념촬영 하는 독도아카데미 대학생
# label: 6
# pred: 0
# ----------------------------------------
# input text: 삼성증권 LG전자 성장 방향성 재평가…목표가↑
# label: 4
# pred: 5
# ----------------------------------------
# input text: 차범K3>지성과 |B 나@히 손3민~지금부터Pq새 역사
# label: 1
# pred: 0
# ----------------------------------------
# input text: 원달러 환율 나흘째 상승
# label: 6
# pred: 5
# ----------------------------------------
# input text: 과학기술 U연기관장W 제주 "전m%정책 공유
# label: 6
# pred: 4
# ----------------------------------------
# input text: 폭로전·삿대질·고성·몸싸움…막장 치닫는 바른미래당
# label: 1
# pred: 2
# ----------------------------------------
# input text: 김해영 청년희망펀드 기부자 절반이 수탁은행 직원
# label: 4
# pred: 5
# ----------------------------------------
# input text: 백의종군 최경환 경북 모임서 족쇄 풀렸다 소회
# label: 0
# pred: 2
# ----------------------------------------
# input text: 크루즈 관광객용 반나절 부산 해안 트레킹 상품 개발
# label: 1
# pred: 0
# ----------------------------------------
# input text: 영상a꼭두 O야기_김W안 r젠가h 저도[저승\갈 +이 오Y9
# label: 3
# pred: 0
# ----------------------------------------
# input text: '대중교통'에서 만난 유명 인사들 유명 인사들 대중교통에 오른 이유
# label: 3
# pred: 0
# ----------------------------------------
# input text: 특검 뇌물죄 수사 공식화…최순실 뇌물 피의자 조사
# label: 3
# pred: 2
# ----------------------------------------
# input text: NH투자 IRP 비보장상품 수익률 업계 1위
# label: 4
# pred: 5
# ----------------------------------------
# input text: 게시판 한은 알기쉬운 경제이야기 UCC 공모전 수상작 선정
# label: 4
# pred: 3
# ----------------------------------------
# input text: 북적이는 송악산 선착장
# label: 1
# pred: 0
# ----------------------------------------
# input text: 해외로밍 어촌 마 1C4t0에B광R역망4구축
# label: 3
# pred: 5
# ----------------------------------------
# input text: 전 세계 참조 이nd 유지 관리 우려 개조
# label: 6
# pred: 4
# ----------------------------------------
# input text: 경남 총선 경쟁률 2.5대1…양산을 4대1 최고
# label: 3
# pred: 2
# ----------------------------------------
# input text: 은성수 조선 기자재 업체 적극 지원…경쟁력 제고 돕겠다
# label: 6
# pred: 5
# ----------------------------------------
# input text: 톈안먼 진압 당시 中장교 공개 참회…6·4 기억해야
# label: 0
# pred: 6
# ----------------------------------------
# input text: 8만B짜리 항공 R1마카Y 나3
# label: 0
# pred: 4
# ----------------------------------------
# input text: 브_질A언론 {세프 V통. 탄핵rM능성 더 커j
# label: 6
# pred: 2
# ----------------------------------------
# input text: 北 김정은 뿔테안경 쓰고 담담한 표정으로 신년사 낭독
# label: 0
# pred: 6
# ----------------------------------------
# input text: o년 2월JbB감z원 8e 5택iqB f약시스템 가 대
# label: 3
# pred: 4
# ----------------------------------------
# input text: 부산H첫 `름다. 자성고20K철거작업 완c
# label: 3
# pred: 0
# ----------------------------------------
# input text: 시베리아서 겨울잠 실패한 갈색곰 민가 습격해 1명 숨져
# label: 1
# pred: 6
# ----------------------------------------
# input text: 모바일 컴퓨팅 미래는…서울서 국제학회 ACM 모비시스 개막
# label: 6
# pred: 4
# ----------------------------------------
# input text: 투표현장 권영진 대구시장 신명여중서 투표
# label: 1
# pred: 2
# ----------------------------------------
# input text: 게시판 NH농협금융 부문장 경영협약 체결
# label: 3
# pred: 5
# ----------------------------------------
# input text: LG전자가 재무사용자보고서 상장 제한
# label: 4
# pred: 5
# ----------------------------------------
# input text: SKT 세계 최초 5G 가입자 100만 명 돌파
# label: 5
# pred: 4
# ----------------------------------------
# input text: 그래픽 c분기?서X인구G2만2천명 순0출
# label: 3
# pred: 5
# ----------------------------------------
# input text: 게시판 EBS대전방송 인재 양성 위한 업무협약
# label: 5
# pred: 4
# ----------------------------------------
# input text: 국토부 차관 지방 미분양이 문제 매수자 입장에선 좋을 수도종합
# label: 0
# pred: 5
# ----------------------------------------
# input text: 좁아진 미국 문에 아메리칸 드림 포기하는 중미 이민자들
# label: 1
# pred: 6
# ----------------------------------------
# input text: 삼성전자 갤럭시S8 체험존 방문객 160만명 넘었다
# label: 1
# pred: 4
# ----------------------------------------
# input text: 하나금투 대우조선해양 LPG선 시장 도전자로 부상
# label: 4
# pred: 5
# ----------------------------------------
# input text: 월 J9l 월째경상수지 흑자 Q자폭은 J18q AT
# label: 6
# pred: 5
# ----------------------------------------
# input text: 이제는 내내 고민한 유연주자 김수지…2019년 상상력 연주대상
# label: 1
# pred: 0
# ----------------------------------------
# input text: 중도금 대출제한도 무색한 청약열기…1순위 마감 줄이어
# label: 0
# pred: 5
# ----------------------------------------
# input text: 이통사 방문판매 급증…올해 다단계 첫 추월
# label: 4
# pred: 5
# ----------------------------------------
# input text: 춘천 MBC 나이야가라 한국방송대상 작품상 수상
# label: 1
# pred: 0
# ----------------------------------------
# input text: 큰절하는 새누리당 당직자들
# label: 1
# pred: 2
# ----------------------------------------
# input text: 이브스남크 N메니스 M 총리에 국 J 협력 f
# label: 2
# pred: 6
# ----------------------------------------
# input text: 올D 민주언론상에<SBS 삼성1관련"연속 보도
# label: 3
# pred: 2
# ----------------------------------------
# input text: 왜 A대자 A 내4노즈 안 6면 못bQ가
# label: 5
# pred: 4
# ----------------------------------------
# input text: 그래픽 oO크t스케일업!추'h략 #요 내용
# label: 5
# pred: 4
# ----------------------------------------
# input text: 국제 사회에서 주인공이 된 한국의 K-POP, 글로벌 상업적 성공
# label: 3
# pred: 0
# ----------------------------------------
# input text: LG U+ 5G 서비스 대중화…아동과 장애인도 무료 제공
# label: 5
# pred: 4
# ----------------------------------------
# input text: 리J에겐 인격적 소S~력 중요…P과만중KA독불`군형은 NO
# label: 0
# pred: 6
# ----------------------------------------
# input text: 특검 이화2대 및 관계자F사무실·4택 (0여+ 1}~색c보
# label: 3
# pred: 2
# ----------------------------------------
# input text: 벨·뮬로바·마이스키…클래식 스타 일주일 간격 줄내한
# label: 0
# pred: 1
# ----------------------------------------
# input text: X신망8Tc단서U스까지세계 yP5G올림픽 눈앞
# label: 4
# pred: 1
# ----------------------------------------
# input text: 국민의 거리에서 무기한 지지 demonstrating
# label: 3
# pred: 2
# ----------------------------------------
# input text: 서울시 인권위 노숙인 공공일자리 축소안 철회 권고
# label: 0
# pred: 3
# ----------------------------------------
# input text: 항생제 생산 유전자 단백질 될 때 버퍼링 걸린다
# label: 5
# pred: 4
# ----------------------------------------
# input text: 두산밥캣 맥스 컨트롤 2019 혁신제품 골드 수상
# label: 5
# pred: 4
# ----------------------------------------
# input text: 與 대구·경북 공천면접심사…현역 vs 진박 격돌
# label: 1
# pred: 2
# ----------------------------------------
# input text: 게임정보 네이버웹툰 원작 게임 메이비 오픈베타 外
# label: 5
# pred: 4
# ----------------------------------------
# input text: 네이버·LGU 지체 장애인에 AI스피커·음원 이용권 전달
# label: 5
# pred: 4
# ----------------------------------------
# input text: 은성수 후보자 위기라고 하다 보면 정말 위기가 온다
# label: 1
# pred: 2
# ----------------------------------------
# input text: 제주소식 TBN 제주 개국 2주년 14시간 특별생방송
# label: 3
# pred: 0
# ----------------------------------------
# input text: 北~w은/기동훈련SO접 `A…o행^r도%참관종합
# label: 2
# pred: 6
# ----------------------------------------
# input text: 대우건설산업은행 동반성장펀드 조성…협력사 지원
# label: 4
# pred: 5
# ----------------------------------------
# input text: 장마 때문에…전국 해수욕장 유명산 관광지 썰렁
# label: 6
# pred: 0
# ----------------------------------------
# input text: 호텔서 스타 셰프 음식 만난다…더플라자 레스토랑 4곳 오픈
# label: 1
# pred: 0
# ----------------------------------------
# input text: 北 유엔제재로 수출막힌 석탄 발전에 사용…전력난 완화
# label: 5
# pred: 6
# ----------------------------------------
# input text: LG전자가 3월 30일부터 3월 31일까지 'LG U+ 5G 혁신대상' 수상자 선정
# label: 5
# pred: 4
# ----------------------------------------
# input text: 포천아트밸리서 높이 45ｍ 절벽 배경 야간 공중쇼
# label: 1
# pred: 0
# ----------------------------------------
# input text: 연구실 안D 산업 육성해"yL한 연구L 만8다
# label: 3
# pred: 4
# ----------------------------------------
# input text: 베I린 e하모?서 한V 오케+트o 평화염원`소리 P든다
# label: 0
# pred: 6
# ----------------------------------------
# input text: v플 앱스*어[애플뮤직 9월g터j원<z2제 .원
# label: 5
# pred: 4
# ----------------------------------------
# input text: 공사 기간 비용 1xxb nM크l EJ사업 c주k
# label: 5
# pred: 4
# ----------------------------------------
# input text: 특징X mx소 q7적R전망Q1강력
# label: 5
# pred: 4
# ----------------------------------------
# input text: 국]tb다른S나라도 北핵실험 몰라…美I中k 통t^해
# label: 2
# pred: 6
# ----------------------------------------
# input text: 포스&ICT현f로보틱스 스6트팩토리 사0에 H손
# label: 5
# pred: 4
# ----------------------------------------
# input text: 황교안 오늘 세월호 일반인 희생자 5주기 추모제 참석
# label: 6
# pred: 2
# ----------------------------------------
# input text: 코트라 소비재와 부품으로 미국 시장 공략해야
# label: 4
# pred: 5
# ----------------------------------------
# input text: 조코위w김정J FK여석3fqn민Z보D 사K 내부
# label: 3
# pred: 2
# ----------------------------------------
# input text: 현장 서울시장은 나야 나…박원순·김문수·안철수 첫 유세 장소는
# label: 1
# pred: 2
# ----------------------------------------
# input text: 靑 국민청원 중복참여 가능성 제기…카카오톡 참여 임시중단
# label: 3
# pred: 2
# ----------------------------------------
# input text: 朴대통령 b드 결정후o첫6다자회의…中정E과 접: ~을까
# label: 6
# pred: 2
# ----------------------------------------
# input text: R화감독 같O 지휘자 :타지 영n 같은 k러A교향곡
# label: 1
# pred: 0
# ----------------------------------------
# input text: LG화학 전기차 자산 가치 1조달러를 넘기기
# label: 4
# pred: 5
# ----------------------------------------
# input text: 中 위안화 절)행u…고시 R]값l25개월만I 최고
# label: 6
# pred: 5
# ----------------------------------------
# input text: 교육부교사노조연맹_본교E <%식
# label: 0
# pred: 3
# ----------------------------------------
# input text: 갤럭시 신형 내달 9일 동시시 유력가 0만원K
# label: 5
# pred: 4
# ----------------------------------------
# input text: 중소기업 JB 경기(망 부정적…인건비 올라|최대 애로
# label: 3
# pred: 5
# ----------------------------------------
# input text: 나경원 원내대표, '자전거 1위' 전성기… 1년 만에 2위로 밀려나
# label: 1
# pred: 2
# ----------------------------------------
# input text: 75  t고B3도5후근소나기는 찔끔
# label: 0
# pred: 3
# ----------------------------------------
# input text: 특징주 삼성전자 엿새 만에 약세 전환
# label: 4
# pred: 5
# ----------------------------------------
# input text: 청년 1요BM전국 vvX큰일dT감fcNM세요
# label: 0
# pred: 3
# ----------------------------------------
# input text: 北 남조선 사드 배치하면 주변국의 1차적 타격 대상될 것
# label: 2
# pred: 6
# ----------------------------------------
# input text: 2026년 민간 우주개발시대 연다…달착륙은 2030년 목표종합
# label: 3
# pred: 4
# ----------------------------------------
# input text: 정치적 인권 강화 의제 논란 정당 간 합의 발전
# label: 3
# pred: 2
# ----------------------------------------
# input text: u베 일본 Bx8해 마리오처럼 싸우겠다 D]C 투자 호소
# label: 6
# pred: 5
# ----------------------------------------
# input text: 네이버TV캐스트 네이버TV로 새 단장…모바일 편의성↑
# label: 5
# pred: 4
# ----------------------------------------
# input text: 최병륜 울산MBC 사장
# label: 4
# pred: 5
# ----------------------------------------
# input text: 이스라엘 역사 녹은 희비극 말 한 마리…
# label: 0
# pred: 6
# ----------------------------------------
# input text: 안종범/崔u딩 마사지# 단골손님 9:에 명백한 오보
# label: 3
# pred: 2
# ----------------------------------------
# input text: 북미 평화 통일 원집단 탈북에 즉 FXt 내라 요구
# label: 2
# pred: 6
# ----------------------------------------
# input text: 상장·신작 대박 겹경사에 넷마블 첫 깜짝 보너스
# label: 4
# pred: 5
# ----------------------------------------
# input text: 부동산 재정자금 유출 여부 조사…재정적자 1인당 2억원
# label: 3
# pred: 5
# ----------------------------------------
# input text: 사이버테러 대비 IT기반시설 142곳 긴급 보안점검종합
# label: 5
# pred: 4
# ----------------------------------------
# input text: 세계 첫 5G폰 갤럭시S10 5G 출고가 139만7천원 확정종합
# label: 5
# pred: 4
# ----------------------------------------
# input text: 카톡방 URL 검색 노출 개인정보법 위반 소지 약해
# label: 5
# pred: 4
# ----------------------------------------
# input text: 산천어축제 창작썰매 경주 진짜 이기고 싶다
# label: 1
# pred: 0
# ----------------------------------------
# input text: 코U닥 vl 갈증 풀리나…기술 J고서 매"HY0여.U발=
# label: 5
# pred: 4
# ----------------------------------------
# input text: 미중 무역분쟁 빅뉴스 기대감에 원달러 환율 하락
# label: 6
# pred: 5
# ----------------------------------------
# input text: 답변하는 강수진 국립발레단장
# label: 1
# pred: 0
# ----------------------------------------
# input text: 오륙도등대를 덮치는 거대한 파도
# label: 6
# pred: 0
# ----------------------------------------
# input text: 민주 평창올림픽 성공 개최 총력전…색깔론 한국당 맹공
# label: 1
# pred: 2
# ----------------------------------------
# input text: 가이드북 NO…스마트폰 AI 비서 여행 도우미로 수요↑
# label: 5
# pred: 4
# ----------------------------------------
# input text: SK텔레콤x기050Y이면 마트ia정 끝
# label: 5
# pred: 4
# ----------------------------------------
# input text: 유영민 미래부장관 개혁 예고…새 술은 새 부대에종합
# label: 5
# pred: 2
# ----------------------------------------
# input text: 울산중부새일센터 직업교육으로 경력단절여성 19명 취업 지원
# label: 0
# pred: 3
# ----------------------------------------
# input text: 오바f4폭1마사X6210f 대규1A감R누적 b자m562b
# label: 6
# pred: 5
# ----------------------------------------
# input text: .양피5에프 h5억원i{모 플랜트설비 납품 계약
# label: 4
# pred: 5
# ----------------------------------------
# input text: 미국과 유럽의 에너지 수요 대비 차이
# label: 6
# pred: 5
# ----------------------------------------
# input text: 트럼프 주장대로 불법이민자 전원 추방시 미국 경제 2% 축소
# label: 5
# pred: 6
# ----------------------------------------
# input text: 네이버 이미지 검색 고도화…DB 2배 이상 확대
# label: 5
# pred: 4
# ----------------------------------------
# input text: 8방부 北핵실험gO능p 예의주시r}S든9할 수 V어
# label: 2
# pred: 6
# ----------------------------------------
# input text: 트럼프 배신 코언 의회 증언 연기…가족들 협박받아
# label: 2
# pred: 6
# ----------------------------------------
# input text: 정치 S렘린궁 김정은 J원2UhGF하반기 러시아M방문H합2A
# label: 2
# pred: 6
# ----------------------------------------
# input text: 5G 스마7폰 Y대 기본M금 오#다…월 5만5천원F]종합
# label: 5
# pred: 4
# ----------------------------------------
# input text: LG전자 미국서 G6 사면 구글 홈 준다
# label: 5
# pred: 4
# ----------------------------------------
# input text: 특징주/ 1폰X 조기t단종설T|부품주 급락종합
# label: 4
# pred: 5
# ----------------------------------------
# input text: SKT 010 ntl943 사용 갈j우려정부z문제Nt
# label: 5
# pred: 4
# ----------------------------------------
# input text: 마크롱 최측근 佛 하원의장 부패 의혹 다시 수사받아
# label: 2
# pred: 6
# ----------------------------------------
# input text: DMG69원c모 스플이2패널 제조 공급 계약
# label: 5
# pred: 4
# ----------------------------------------
# input text: 영상 선출부터 퇴장까지…나경원 원내대표 파란만장 1년
# label: 1
# pred: 2
# ----------------------------------------
# input text: RI서이36일째 단J x9wU건강 악화b 병원종합
# label: 3
# pred: 5
# ----------------------------------------
# input text: 건설업계 부실벌점 개정안 기업에 사망선고…철회돼야 주장
# label: 3
# pred: 5
# ----------------------------------------
# input text: 홍콩 갑부 리카싱 올해 세계경제 복잡할 것…모두 조심해야
# label: 6
# pred: 5
# ----------------------------------------
# input text: 중고차 판매점 1만점, '차량의 재활용' 성공 사례
# label: 3
# pred: 5
# ----------------------------------------
# input text: 미래에셋대우 엔씨소프트 매출 1위 굳건…목표가↑
# label: 4
# pred: 5
# ----------------------------------------
# input text: 전북교육청 8월 14일까지 학생 운동선수 폭력피해 실태조사
# label: 0
# pred: 3
# ----------------------------------------
# input text: 현대중공업 4천만달러 규모 산업용 로봇 대량 수주
# label: 4
# pred: 5
# ----------------------------------------
# input text: 韓 물가 7c 초미세먼지-세계 최M…관Zugq 걸림돌
# label: 3
# pred: 5
# ----------------------------------------
# input text: 日언론 文대통령 역사 문제 언급 자제…대일 비난 억제종합
# label: 2
# pred: 6
# ----------------------------------------
# input text: 갤S4D연휴 첫Y 2만2천대O개흥행 b어갈까
# label: 4
# pred: 5
# ----------------------------------------
# input text: 웨어러블 로봇·드론 이용한 이색 퍼포먼스 로봇나무
# label: 0
# pred: 4
# ----------------------------------------
# input text: 우리은행 디지털전환 가속화…과제 발굴해 적극 추진
# label: 4
# pred: 5
# ----------------------------------------
# input text: 중고차 장터 '아기용차' 대가 수수료 5배로 인상
# label: 3
# pred: 5
# ----------------------------------------
# input text: 게시| 예^}독거노] h 고치기 봉사활동
# label: 0
# pred: 3
# ----------------------------------------
# input text: 디아이씨 종속회사 쿠팡에 전기화물차 10대 공급 계약
# label: 4
# pred: 5
# ----------------------------------------
# input text: 2018 ICT 삼성 폴더블폰 새해 애플 아이폰X 대항마될까
# label: 5
# pred: 4
# ----------------------------------------
# input text: 충북소식 도교육청 청렴 콘텐츠 공모전서 우수상
# label: 0
# pred: 3
# ----------------------------------------
# input text: 국내 ICT업계 LGk통1 202년 2c조 추
# label: 4
# pred: 5
# ----------------------------------------
# input text: 국제 5 신흥시장 상이 C드H 2색화에E많F y8점
# label: 6
# pred: 5
# ----------------------------------------
# input text: 네이버 전문자료 검색 내년 안에 구글 따라잡을 것
# label: 5
# pred: 4
# ----------------------------------------
# input text: 그리스 조만간 10년물 국고채 발행…구제금융 이후 처음
# label: 6
# pred: 5
# ----------------------------------------
# input text: 지식재산권 소송로 인한 대형 기업의 재정적 어려움
# label: 4
# pred: 5
# ----------------------------------------
# input text: 특징주 메가B디(자회사 합병에 급W
# label: 4
# pred: 5
# ----------------------------------------
# input text: 우진비앤지 37억 규모 동물용의약품 공급계약
# label: 4
# pred: 5
# ----------------------------------------
# input text: LG유플러스 U파손도움 서비스 확대
# label: 5
# pred: 4
# ----------------------------------------
# input text: 北 김h# 주체조Z의 Q용UO 더 많이C-아올려V
# label: 2
# pred: 6
# ----------------------------------------
# input text: 애플 c이 kt서 2루만 Noe천3kG등w대박
# label: 5
# pred: 4
# ----------------------------------------
# input text: 넥슨 게;/버}진 개발사 아이펀팩`리에 전"적 투자
# label: 4
# pred: 5
# ----------------------------------------
# input text: 특징주 삼성SDI 실적 개선에 강세종합
# label: 4
# pred: 5
# ----------------------------------------
# input text: 세계 5대 경제국들 수출 감소…중국, 미국, 일본, 유럽, 인도
# label: 6
# pred: 5
# ----------------------------------------
# input text: 여성가족부, "가족의 미래를 위한 문화교육" 강화
# label: 0
# pred: 3
# ----------------------------------------
# input text: 이통시장 태풍의 눈 단말 자급제 수면 위로…업계 예의주시
# label: 5
# pred: 4
# ----------------------------------------
# input text: 삼성fW트llc사 긍정 평결rw수시사
# label: 4
# pred: 5
# ----------------------------------------
# input text: $T 화@;의 가a! 기업용7전D R시
# label: 5
# pred: 4
# ----------------------------------------
# input text: 애플 국내서도 아이폰 보상판매…아이폰XR 69만원부터
# label: 5
# pred: 4
# ----------------------------------------
# input text: 스마트폰에 신용카드 대면 삑 새 본인 인증 나온다
# label: 5
# pred: 4
# ----------------------------------------
# input text: 대신증 아7레퍼시픽 신IXE 경로 목적가
# label: 5
# pred: 4
# ----------------------------------------
# input text: SKT 프리미엄 임대폰 제공…10일 이하도 하루 단위 과금
# label: 5
# pred: 4
# ----------------------------------------
# input text: 하나 투q삼성전기 2D기 실|c기eC이하[목표(↓
# label: 5
# pred: 4
# ----------------------------------------
# input text: 삼성SDI 배터리 자산가치 상승
# label: 4
# pred: 5
# ----------------------------------------
# input text: 테슬라 4분기 연속 흑자…국내 2차전지 업체 수혜 기대
# label: 4
# pred: 5
# ----------------------------------------
# input text: 당국 핀테크위크 참여할 레그테크·섭테크 기업 모집
# label: 4
# pred: 5
# ----------------------------------------
# input text: SKTY5S4 l00만명1K 파5Gx비개시 14q2만
# label: 5
# pred: 4
# ----------------------------------------
# input text: 간편결제 i 1위yL모바일결 OICi삼성페 2U
# label: 5
# pred: 4
# ----------------------------------------

# %%
train[train['text']=='WNBA 박지수 LA 스파크스 상대로 2득점 2리바운드']

train.to_csv('../../v1.2.3/train.csv', index=False)

# %%
from cleanlab.dataset import health_summary
class_names = range(7)
health_summary(train['target'], pred_probs, class_names=class_names)
# Out:
# ----------------------------------------------------------
# |  Generating a Cleanlab Dataset Health Summary          |
# |   for your dataset with 3,250 examples and 7 classes.  |
# |  Note, Cleanlab is not a medical doctor... yet.        |
# ----------------------------------------------------------
#
# Overall Class Quality and Noise across your dataset (below)
# ------------------------------------------------------------
#    Class Name  Class Index  Label Issues  Inverse Label Issues  Label Noise  \
# 0           5            5            83                   116     0.186937
# 1           3            3            76                    16     0.185819
# 2           4            4            67                   101     0.149220
# 3           0            0            69                    60     0.143154
# 4           6            6            62                    65     0.132479
# 5           1            1            73                    45     0.123939
# 6           2            2            43                    70     0.105134
#
#    Inverse Label Noise  Label Quality Score
# 0             0.243187             0.813063
# 1             0.045845             0.814181
# 2             0.209110             0.850780
# 3             0.126850             0.856846
# 4             0.138004             0.867521
# 5             0.080214             0.876061
# 6             0.160550             0.894866
# Class Overlap. In some cases, you may want to merge classes in the top rows (below)
# -----------------------------------------------------------------------------------
#     Class Name A  Class Name B  Class Index A  Class Index B  \
# 0              4             5              4              5
# 1              0             1              0              1
# 2              2             6              2              6
# 3              5             6              5              6
# 4              3             5              3              5
# 5              0             3              0              3
# 6              1             2              1              2
# 7              2             3              2              3
# 8              1             4              1              4
# 9              0             4              0              4
# 10             0             6              0              6
# 11             4             6              4              6
# 12             0             5              0              5
# 13             1             6              1              6
# 14             0             2              0              2
# 15             1             5              1              5
# 16             3             4              3              4
# 17             2             5              2              5
# 18             2             4              2              4
# 19             1             3              1              3
# 20             3             6              3              6
#
#     Num Overlapping Examples  Joint Probability
# 0                         94           0.028923
# 1                         41           0.012615
# 2                         38           0.011692
# 3                         38           0.011692
# 4                         28           0.008615
# 5                         24           0.007385
# 6                         24           0.007385
# 7                         21           0.006462
# 8                         21           0.006462
# 9                         18           0.005538
# 10                        17           0.005231
# 11                        16           0.004923
# 12                        16           0.004923
# 13                        15           0.004615
# 14                        13           0.004000
# 15                        13           0.004000
# 16                        12           0.003692
# 17                        10           0.003077
# 18                         7           0.002154
# 19                         4           0.001231
# 20                         3           0.000923
#  * Overall, about 10% (327 of the 3,250) labels in your dataset have potential issues.
#  ** The overall label health score for this dataset is: 0.90.
#
# Generated with <3 from Cleanlab.
# {'overall_label_health_score': 0.8993846153846153,
#  'joint': array([[0.12707692, 0.00553846, 0.00338462, 0.00338462, 0.00369231,
#          0.00276923, 0.00246154],
#         [0.00707692, 0.15876923, 0.00646154, 0.00030769, 0.00430769,
#          0.00184615, 0.00246154],
#         [0.00061538, 0.00092308, 0.11261538, 0.00061538, 0.00215385,
#          0.00123077, 0.00769231],
#         [0.004     , 0.00092308, 0.00584615, 0.10246154, 0.00338462,
#          0.00830769, 0.00092308],
#         [0.00184615, 0.00215385, 0.        , 0.00030769, 0.11753846,
#          0.01538462, 0.00092308],
#         [0.00215385, 0.00215385, 0.00184615, 0.00030769, 0.01353846,
#          0.11107692, 0.00553846],
#         [0.00276923, 0.00215385, 0.004     , 0.        , 0.004     ,
#          0.00615385, 0.12492308]]),
#  'classes_by_label_quality':    Class Name  Class Index  Label Issues  Inverse Label Issues  Label Noise  \
#  0           5            5            83                   116     0.186937
#  1           3            3            76                    16     0.185819
#  2           4            4            67                   101     0.149220
#  3           0            0            69                    60     0.143154
#  4           6            6            62                    65     0.132479
#  5           1            1            73                    45     0.123939
#  6           2            2            43                    70     0.105134
#
#     Inverse Label Noise  Label Quality Score
#  0             0.243187             0.813063
#  1             0.045845             0.814181
#  2             0.209110             0.850780
#  3             0.126850             0.856846
#  4             0.138004             0.867521
#  5             0.080214             0.876061
#  6             0.160550             0.894866  ,
#  'overlapping_classes':     Class Name A  Class Name B  Class Index A  Class Index B  \
#  0              4             5              4              5
#  1              0             1              0              1
#  2              2             6              2              6
#  3              5             6              5              6
#  4              3             5              3              5
#  5              0             3              0              3
#  6              1             2              1              2
#  7              2             3              2              3
#  8              1             4              1              4
#  9              0             4              0              4
#  10             0             6              0              6
#  11             4             6              4              6
#  12             0             5              0              5
#  13             1             6              1              6
#  14             0             2              0              2
#  15             1             5              1              5
#  16             3             4              3              4
#  17             2             5              2              5
#  18             2             4              2              4
#  19             1             3              1              3
#  20             3             6              3              6
#
#      Num Overlapping Examples  Joint Probability
#  0                         94           0.028923
#  1                         41           0.012615
#  2                         38           0.011692
#  3                         38           0.011692
#  4                         28           0.008615
#  5                         24           0.007385
#  6                         24           0.007385
#  7                         21           0.006462
#  8                         21           0.006462
#  9                         18           0.005538
#  10                        17           0.005231
#  11                        16           0.004923
#  12                        16           0.004923
#  13                        15           0.004615
#  14                        13           0.004000
#  15                        13           0.004000
#  16                        12           0.003692
#  17                        10           0.003077
#  18                         7           0.002154
#  19                         4           0.001231
#  20                         3           0.000923  }
