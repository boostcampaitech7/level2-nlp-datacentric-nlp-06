# %%
import os
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import re

import evaluate
import torch
from torch.utils.data import Dataset, DataLoader

from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers import DataCollatorWithPadding
from transformers import TrainingArguments, Trainer

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# konlpy
import konlpy
from konlpy.tag import Okt

# Seed Set
SEED = 456
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)

# 디바이스 설정 (GPU가 사용 가능하면 GPU를 사용하고, 그렇지 않으면 CPU 사용)
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# # ASCII-code 기반으로 노이즈 체크

# %%
data_path = os.path.join('..', '..', 'data')
data = pd.read_csv(os.path.join(data_path,"train.csv"))
print(data_path)
# Out:
# ../../data

# %%
data.head()
# Out:
#                     ID                              text  target
# 0  ynat-v1_train_00000  정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1  ynat-v1_train_00001       K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2  ynat-v1_train_00002            m 김정) 자주통일 새,?r열1나가야1보       2
# 3  ynat-v1_train_00003     갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       5
# 4  ynat-v1_train_00004      pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6

# %%
text_datas = data["text"]
text_datas
# Out:
# 0        정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보
# 1             K찰.국DLwo 로L3한N% 회장 2 T0&}송=
# 2                  m 김정) 자주통일 새,?r열1나가야1보
# 3           갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩
# 4            pI美대선I앞두고 R2fr단 발] $비해 감시 강화
#                       ...
# 2795    트럼프 폭스뉴스 앵커들 충성도 점수매겨…10점만점에 12점도
# 2796          삼성 갤럭시S9 정식 출시 첫 주말 이통시장 잠잠
# 2797     텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보
# 2798      인터뷰 류현진 친구에게 안타 맞는 것 싫어해…승부는 냉정
# 2799                 지능정보사회 대비 국가 종합대책 마련
# Name: text, Length: 2800, dtype: object

# %%
def calculate_ascii_noise(text):
    total_chars = len(text)
    ascii_chars = 0 
    for ch in text:
        if ch == " ":
            continue
        if ord(ch) < 128:
            ascii_chars+=1
            
    non_ascii_chars = total_chars - ascii_chars  # 비-ASCII 문자 개수
    
    ascii_ratio = (ascii_chars / total_chars) * 100  # ASCII 문자 비율 (%)
    
    return ascii_chars, non_ascii_chars, ascii_ratio

# %%
asc_counts = []; non_asc_counts = []; percentages = []
# ASCII 문자 개수, 비-ASCII 문자 개수, ASCII 비율 계산
for text_with_noise in text_datas:
    ascii_count, non_ascii_count, ascii_percentage = calculate_ascii_noise(text_with_noise)
    ascii_percentage = round(ascii_percentage,2)
    asc_counts.append(ascii_count)
    non_asc_counts.append(non_ascii_count)
    percentages.append(ascii_percentage)
    
print(len(asc_counts), len(non_asc_counts), len(percentages))
# Out:
# 2800 2800 2800

# %%
data["ascii_counts"] = asc_counts
data["non_ascii_counts"] = non_asc_counts
data["ratio"] = percentages

# %%
Noise_data = data[data["ratio"]<30]
Noise_data[Noise_data["ratio"]>25]
# Noise_data.to_csv(os.path.join(data_path,"train_Noise_data_ascii.csv"),encoding="utf-8-sig")
# Out:
#                        ID                                text  target  \
# 33    ynat-v1_train_00033                     학~ 석면 S거 규정k지키5       3
# 66    ynat-v1_train_00066  UEFA 챔스리그 4강 마드리드 더비 성사…레알 vs 아...       0
# 76    ynat-v1_train_00076         北조국통!민주X#전선 결성 <0돌 중;보고회 열x       2
# 126   ynat-v1_train_00126     날씨-미z먼지 보통 수y…오후부터 xJ지고:곳곳 F12일       0
# 138   ynat-v1_train_00138           삼성 빅스. 개발자데KS1B월 서울B 첫 +최       4
# ...                   ...                                 ...     ...
# 2739  ynat-v1_train_02739         :한금투 자동차 업/ 1분기부k5실적 점진?|I선       5
# 2741  ynat-v1_train_02741       ~ 전 앞둔eW재 감98T이 부K되지만  4로 승부수       1
# 2745  ynat-v1_train_02745         軍v<들 전용3량 타고 골l장y…`덕적 해R 심각       3
# 2780  ynat-v1_train_02780         北0대! 김정*2향한 "성경쟁 무대된l릴레이r토론       2
# 2789  ynat-v1_train_02789         이총리,세4. H직 완fl지 못해E할 일 꽤;남아       2
#
#       ascii_counts  non_ascii_counts  ratio
# 33               4                11  26.67
# 66              10                24  29.41
# 76               7                20  25.93
# 126              9                22  29.03
# 138              7                18  28.00
# ...            ...               ...    ...
# 2739             8                19  29.63
# 2741             8                21  27.59
# 2745             7                20  25.93
# 2780             7                20  25.93
# 2789             8                19  29.63
#
# [143 rows x 6 columns]

# %%
Label_noise_data = data[data["ratio"]<30]
Label_noise_data.to_csv(os.path.join(data_path,"train_Label_noise_data_ascii.csv"),encoding="utf-8-sig")

# %%
data_30p = data[data["ratio"]<30.0].reset_index(drop=True).to_csv(os.path.join(data_path,"train_30p_ASCII_removed.csv"),encoding="utf-8-sig")

# %%
text_datas[text_datas["ratio"]<35.0].iloc[29]
# Out:
# ID                              ynat-v1_train_00090
# text                서울문고 N풍그U에 인수… f라인서점 교m영풍y양강d도로
# ascii_counts                                     10
# non_ascii_counts                                 21
# ratio                                         32.26
# Name: 90, dtype: object

# %% [markdown]
# 생각보다 ..판단하기가 어려움.. 그렇다면 ASCII 코드를 MASK 토큰으로 하고 BART를 한다면?

# %% [markdown]
# # BART Test

# %%
from transformers import BartForConditionalGeneration, PreTrainedTokenizerFast, AutoModelForSeq2SeqLM

tokenizer = PreTrainedTokenizerFast.from_pretrained('gogamza/kobart-base-v2')
model = BartForConditionalGeneration.from_pretrained('gogamza/kobart-base-v2')

# tokenizer = PreTrainedTokenizerFast.from_pretrained('kfkas/t5-large-korean-news-title-klue-ynat')
# model = AutoModelForSeq2SeqLM.from_pretrained("kfkas/t5-large-korean-news-title-klue-ynat")
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
print(tokenizer.all_special_ids)
print(tokenizer.all_special_tokens)
# Out:
# [1, 5, 3, 6]
# ['</s>', '<unk>', '<pad>', '<mask>']

# %%
def replace_ascii_with_mask(text):
    # 결과를 저장할 리스트
    result = []
    
    # 입력 문자열을 한 문자씩 순회
    for char in text:
        # 공백은 그대로 추가
        if char == ' ':
            result.append(char)
        # ASCII 코드 범위(0 ~ 127) 확인, 공백 제외
        elif ord(char) <= 127:
            # ASCII 문자면 <mask>로 대체
            result.append('[MASK]')
        else:
            # 그렇지 않으면 원래 문자를 그대로 추가
            result.append(char)
    
    # 리스트를 문자열로 변환하여 반환
    return ''.join(result)

# %%
input_text = "서울문고 N풍그U에 인수… f라인서점 교m영풍y양강d도로"
# input_ids = tokenizer(input_text, return_tensors='pt')['input_ids']
input_ids = tokenizer(replace_ascii_with_mask(input_text), return_tensors='pt')['input_ids']

# %%
output_text = tokenizer.decode(input_ids[0], skip_special_tokens=True)
output_text
# Out:
# '서울문고  풍그 에 인수...  라인서점 교 영풍 양강 도로'

# %%
output_ids = model.generate(
    input_ids, 
    max_length=50, 
    early_stopping=True,
    num_beams=4,
    no_repeat_ngram_size=2,  # 3-그램 이상의 반복 방지
    temperature=0.7,         # 다양성 조절
    top_p=0.92,
    top_k=50
)

# 복원된 텍스트 디코딩
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_text)
# Out:
# 서울문고  풍그르 에 인수...  라인서점 교보문고, 영풍문고와 양강도로 도로 도로.  도로와 도로의 도로문고가  양천구 신월동 도로에 도로교

# %% [markdown]
# # BERT TEST

# %% [markdown]
# Fill-Mask BERT Model Test

# %%
from transformers import pipeline, AutoModelForMaskedLM
# monologg/koelectra-base-v3-generator
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-generator", use_fast=True)
model = AutoModelForMaskedLM.from_pretrained("monologg/koelectra-base-v3-generator")
fill_mask = pipeline(
    "fill-mask",
    model=model,
    tokenizer=tokenizer
)
print("MASK Token :",tokenizer.mask_token)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# MASK Token : [MASK]

# %%
input_text = "프로야구~롯TKIAs광주 경기 y천취소"
replace_text = replace_ascii_with_mask(input_text)
print(replace_text)
# input_ids = tokenizer(input_text, return_tensors='pt')['input_ids']
predictions = fill_mask(replace_text)
# Out:
# 프로야구[MASK]롯[MASK][MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소

# %%
def fill_multiple_masks(sentence, fill_mask):
    while "[MASK]" in sentence:
        # 현재 문장에서 첫 번째 [MASK]만 복원
        # print("MASK token Detected, Now Sentence :",sentence)
        predictions = fill_mask(sentence)
        # 가장 높은 확률의 예측을 선택
        best_prediction = predictions[0]
        # 첫 번째 [MASK]를 예측된 단어로 대체
        try:
            sentence = sentence.replace("[MASK]", best_prediction[0]['token_str'], 1)
        except:
            sentence = sentence.replace("[MASK]", best_prediction['token_str'], 1)
        # 복원된 문장 출력
        # print(f"복원 진행 중: {sentence}")
    return sentence

filled_sentence = fill_multiple_masks(replace_text, fill_mask)
# Out:
# MASK token Detected, Now Sentence : 프로야구[MASK]롯[MASK][MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯[MASK][MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯[MASK][MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지[MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯##지[MASK][MASK][MASK][MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지##덕[MASK][MASK][MASK]광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯##지##덕[MASK][MASK][MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지##덕##구[MASK][MASK]광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯##지##덕##구[MASK][MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지##덕##구)[MASK]광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯##지##덕##구)[MASK]광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지##덕##구)’광주 경기 [MASK]천취소
# MASK token Detected, Now Sentence : 프로야구‘롯##지##덕##구)’광주 경기 [MASK]천취소
# 복원 진행 중: 프로야구‘롯##지##덕##구)’광주 경기 ##구장천취소

# %%
# 입력 텍스트
text = "프로야구‘롯##지##덕##구)’광주 경기 ##구장천취소"

def merge_subwords(text):
    return re.sub(r'\s?##', '', text)

def remove_special_chars(text):
    return re.sub(r'#', '', text)

text = merge_subwords(text)

text = remove_special_chars(text)

# 결과 출력
print("후처리된 텍스트:", text)
# 실제 기사 : 서울문고, 영풍그룹에 인수…오프라인서점 교보-영풍 양강구도로
# Out:
# 후처리된 텍스트: 프로야구‘롯지덕구)’광주 경기구장천취소

# %% [markdown]
# Noise Data 처리

# %%
Noise_text_data = Noise_data[["ID","text","target"]]

# %%
Noise_text_data
# Out:
#                        ID                              text  target
# 0     ynat-v1_train_00000  정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1     ynat-v1_train_00001       K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2     ynat-v1_train_00002            m 김정) 자주통일 새,?r열1나가야1보       2
# 4     ynat-v1_train_00004      pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6
# 6     ynat-v1_train_00006             프로야구~롯TKIAs광주 경기 y천취소       1
# ...                   ...                               ...     ...
# 2786  ynat-v1_train_02786         텅 빈 }실 선생님+홀K Y|q% T+X C1       3
# 2787  ynat-v1_train_02787   13이 노바 라이n2·미J어패0 T3 10 결G상품% *       6
# 2788  ynat-v1_train_02788                남원소식 춘>X학%단+장Rn 모집       0
# 2792  ynat-v1_train_02792       높`X#E율…}BO Q"[/선수 몸값 상승 CAO       1
# 2797  ynat-v1_train_02797  텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보       4
#
# [1285 rows x 3 columns]

# %%
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-generator", use_fast=True)
model = AutoModelForMaskedLM.from_pretrained("monologg/koelectra-base-v3-generator")
fill_mask = pipeline(
    "fill-mask",
    model=model,
    tokenizer=tokenizer
)
print("MASK Token :",tokenizer.mask_token)

processed_data = []

def fill_multiple_masks(sentence, fill_mask):
    while "[MASK]" in sentence:
        # 현재 문장에서 첫 번째 [MASK]만 복원
        # print("MASK token Detected, Now Sentence :",sentence)
        predictions = fill_mask(sentence)
        # 가장 높은 확률의 예측을 선택
        best_prediction = predictions[0]
        # 첫 번째 [MASK]를 예측된 단어로 대체
        try:
            sentence = sentence.replace("[MASK]", best_prediction[0]['token_str'], 1)
        except:
            sentence = sentence.replace("[MASK]", best_prediction['token_str'], 1)
        # 복원된 문장 출력
    # print(f"복원 데이터: {sentence}")
    return sentence

def merge_subwords(text):
    return re.sub(r'\s?##', '', text)

def remove_special_chars(text):
    return re.sub(r'#', '', text)

def fill_MASK_using_BERT(input_text, fill_mask):
    
    # Fill - Mask
    replace_text = replace_ascii_with_mask(input_text)
    filled_sentence = fill_multiple_masks(replace_text, fill_mask)
    # Post-processing
    post_processed_data = merge_subwords(filled_sentence)
    post_processed_data = remove_special_chars(post_processed_data)
    # 결과 출력
    # print("후처리된 텍스트:", text)
    # print("========================")
    processed_data.append(post_processed_data)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# MASK Token : [MASK]

# %%
for noise_text in Noise_text_data["text"]:
    fill_MASK_using_BERT(noise_text, fill_mask)

# %%
processed_data
# Out:
# ['정씨리파 미사 미사 이용기간 단품 분종보',
#  "'찰라국의라국 로한길다 회장  라국송",
#  '- 김정숙 자주통일 새정치는이제열은나가야보',
#  '오바마,美대선을앞두고 오바마,오바마,단 발오바마에비해 감시 강화',
#  '프로야구‘롯지덕구)’광주 경기구장천취소',
#  '그의 매력은모·츠·열·나·약 ·나·주가 고··진',
#  '아이들고딩수리개 대…맥- 디-디레- 디-디레',
#  '문대통령인 당대표의당 민관은동의사위해마에보 철거',
#  '추신수 타율 0.1푼지로 시즌 마감…최지만은 2점홈런·홈런홈런·',
#  '이는그런수단·팬들고께하는호오는그족 한마 최',
#  '현회장차장훈남은 임원을늘려….세. 리. 기보. 육.',
#  '○선 폭의 현장조',
#  '(2015년레콤 )분기 영,익,,천,,,,…….5％ 증가',
#  '생신인증②.안돼제가 유되면 대 가끝',
#  '2014년대건덕후강수나라감독 로축구연맹로축구연맹회부',
#  "''축구'인천 ''' '''운드 ''''영'",
#  '세계적인무역협회 올해는무역인 무역인 천년한번 배출한',
#  '박항의 매직은베트남의축구표팀의힘을 쏟고',
#  '이는이 는 생산 인공광고에는기보다에는활는적',
#  '다저스는버츠 감독은류현전 담당 포수로최 환갑 만들어닝.',
#  '박대통령,2월일 연,상,의장 ,견,창조경제 논의',
#  '산업생산이십년째 고 제조공장가동률은글로벌금융위주는수합보',
#  '그는 유 의는나도못내고사표…특별한번제 흔들',
#  "'자농' ,'은행'삼십여명 꺾고딩직직 직",
#  '김종민리먼 -라더스 사태처럼 세계경제에 충격이지속죽을 것',
#  '이는이자구 김정수트로그보니도모르지는이',
#  '인국공은(태왕삼년)의 은(무)은(공)이고왜진보인가',
#  '美,여성과한여성 비율은계속 가주가대 입생 중가',
#  '위클루돌프스루플코리아루 한국서얼마나 벌을',
#  '찍은는 즐거이 가졌다…두개 카메오는즐거는즐거 큐',
#  '문대통령 김정태스크트프릴 조속히끝내고 다고합',
#  '한·미사이에는 유두바이 치료제 오·솔 美 임· 미수출 본격화',
#  '아사이 트-프 외교는험이없다고….오바도는험지-였다',
#  '이는자객사만명 돌고',
#  '유라와아라경이연합의회심상품회교환 합의',
#  "'부 리수춘식춘'(北)국제사회의임(일원)는데 기를[UNK]",
#  '“콩이면금이 나는…”트는물이나고 지철 기고',
#  '-선민아 울어경공업활성화고용안정소합',
#  '월드볼튼천재 사령탑 시코코비-오 감독 한국전에어닝',
#  '특판상판호에리포포모금조달에서 신고가',
#  '이는내가일리젠지 산 은…법정에… 내 처리하.요',
#  '본,카 애스턴마틴 ,델라 국내에어…에대 생산',
#  '추신수 시는경기에종반타블로넷타율',
#  '[화보]유영준,왕웨이, 모델직 조심스러워…발칵구일밤내',
#  '2015년도한국사이버랜드제스트분기 영업익원하니 감소',
#  '‘리비에브리아,나는 신분 변절’허용…의료보험서로 사전에입해야',
#  '수능에브리아는원플립울 문에서 개한 꽃',
#  '그는를 내비게된션은을을 국민을을 국민',
#  '온몸으론 한방 바루돌프를 느끼다…천원한방스벅벅',
#  '2년 전에어글리터개에매서에 체험인 련',
#  '멀티골잡이순형 로축구그후딱좋운드좋',
#  '구글,구글 ,구글,구글에이어구글,구글,구글,구글 ,구글…….-피커 없는 용',
#  '종이 한면을어도를삼중공 을사삼델로 설때 증받는다',
#  '올수,서훈외어휴울증말하다자이역 .',
#  '이도영덕진자린대 교육·교육·교육목적진허',
#  '한편,한국관광공사와업무협약식체결',
#  '프랑스 마에그의 이 대,, ,, ,청설의인',
#  "'독'멈춤선  데다수·원대·면·점·구· 인·도 무산",
#  '미국에브라더럼광합성하기포공장 개발',
#  '신간 한끗은이랑자스민법동코뮤니트친[UNK]',
#  '朴·朴령 北도발에각한 균주조짐…北주민동요에가는종합',
#  '손경희정 회남 즈베관관 협력방안 의',
#  '朴대통령·시도현정부,일·리·언…지·이 고용·복지 주역종합',
#  '이는몇㎞ 조-우 선동의 독박과정-께 전-고',
#  '선두는도시공사시공사칼텍현진탈연승합',
#  '수) 이는1.인)고) 수)생이확) 잇다확…교파 당국각',
#  '그의1년,제2회 외인투자정협의회',
#  '게일판의자브텔크아이폰아이매 이벤트',
#  '올해도곡동도상에 멀리 개 짖는 소떼가 들었다',
#  '김씨는 몇년째업…',
#  '4대째화점 팝스타듀티파니언-트랩 진',
#  '알림톡 무단으로송·출 카고징',
#  '◇ 친박 원내,표심의원보·유훈 ·단·화·홍문표·표·도·종합',
#  '도자기와작품상판판람객들',
#  '분당·분당· 분당·분당·분당·야··· 야···대·중·대립',
#  '김정은의향있다롄산산시',
#  "'반기 전''''' '''여'…'년보다들고↓",
#  '수협과수협은 공공주택에어보금 보금출',
#  '사법부 판결…불확변상터',
#  '최고의원중심의원의당에하는중교안',
#  '中,정· 지방간민의투의투실태착',
#  '서울에페페카페트온라인 개강좌 공동 개설',
#  '그의픽서울의픽 일강의픽이',
#  '다시말해월 여행의 [UNK]…을 반는 [UNK]딧짝',
#  '[단독 ]사채업행계도약10조원….작년대비업행↑',
#  '-이트삭스윗의수 그다음달 영입…몇년만 천원 달러',
#  "'페이오'중동서'''''국선·동·서·구…이란·고· 강·종'",
#  '명을 옮다 는 즐움…필사의문의지 문을옮고간',
#  '한·미· 파·일사·의동반성장 협치식',
#  '한국의주인공아타타명탐정키 일본의이기…연극이',
#  '이는 러프 타사 고객을대상럭시 험단.',
#  '사는인터넷신  넷투해 미래 먹거리를.',
#  '등을 수있는확한번앞한경',
#  '이를확뚝 떨어뜨린출출에잇도으로 라',
#  '‘‘’ ‘강’대‘ 발’…‘알렌’‘리젠뮌헨 맞다’',
#  '갤리젠지엠비부터까페 환불에만원도',
#  '이는((()나(((()면 속에))) 로스팅시청률상승',
#  '이를먹은립공박 손독유자 집 명패가는다',
#  '이는이다크루다리아 친이[UNK]시설 격동라에 경',
#  '與,몽니·박·박두,한- 선-중 -한-트럼비동참 ,우리당 압니다',
#  '인,그는진군 오전에어닝진진진주,보 해',
#  "'은 문을적한양 풍덩했다들맹개이개 문 행개",
#  '폭군도촬 야밤을 보러 갈려든시민들꽃종화관전시 인기',
#  '美, 사드고지요구에 반정년시즌에 美,사주한대',
#  '--- 선무-장 남자 배--올시즌에출전 충심히 가능하다',
#  '‘아이리시닷컴’개막‘스윗글글은·은·류현진',
#  '여·여·여·여·부·부·드나는라운한국·브라질·미·과 대',
#  '경학동리개 시리오리개시 대설주의보해',
#  '충격적은점 박철우한점 크게 보인다더니 온몸에 쥐났어요',
#  '미에일로에사는 에 앤티…상·화 돌입',
#  '칼드의쉽게열리지말라는 멕시폰골문',
#  '나는하다프트 아이폰예약',
#  '이는길로조 파 외치다 한 번에 당찬승부',
#  '출마금지안나슈야웡 홍아싸나슈원하면 투표해.',
#  '문([UNK])령((임(유)) 헌(헌))) )))판(들과 )께',
#  '최아희의욕먹고딩헬비전 병 사는보다 연종합',
#  '모바일앱을 모바일 시큐리티 모바일앱 모바일로드 돌파',
#  '▶<자베스 여>▶정치권에서>▶<트 타협 촉구',
#  '이는3년대전 기와맞먹 사골 양곡곡전소미[UNK]',
#  '이를만드는명장 바비 콕스로만드',
#  '印공, 파키스탄 내에브라만보니…,등에고조종합',
#  '미국시판 코넬아페페',
#  '朴대통령,北후방테러에대비위해 러방지법',
#  '민주회담성사 앞에둘러북미정당회담에서색야당 힘없다야',
#  '게일판 앱북핑크퐁 튜너 출시',
#  '與,野,위·혁신에 출당·청·…·박 ·발 작용한것들',
#  '대우조선선해양 천년도,억원 한, 운,선 ,척,수주',
#  '지난해말 ‘ 여든 ’주권 인류무형문화유산 해빙화를 나다…㎞ 비[UNK]',
#  '그의픽의픽리 결함',
#  '오늘은 황도연휴해박 이용권을드려요',
#  'CJ그룹&엔터테인먼트 ,분기 영업익 최대1천억원…매출1배 증가',
#  '이는 선유인능 분는천원원 투종합',
#  '연천 영하 (영하)도도…경칩북,오늘오후부턴,강바람위 풀려',
#  '[기소식:부킹] 내가는일도화재 대제',
#  '이말의로운여행 제주여행취향나자…대야 날릴때하얀색 계곡·계곡다 축제',
#  '"징,"코데의컴바디다프 스닥총총종',
#  '송은섭의 회…전국구의원만의선',
#  '푸에 살만한사우디,왕과의살만…유시미 -조 지속 합의종합',
#  '답,한번진빛 하다…경기, 초미세먼지지 주는 다…으.대',
#  '광덕진북구취계나',
#  '공사기간·비용등급조은 …크사업주',
#  '탈북 도와달라한국계영훈남은왕 국가공훈훈장 아',
#  '등단 후일년 장으로남은인 가나 지줬죠',
#  '청·율·김아,김어준의뉴타운공장 청취의뉴는가찌',
#  '프릴구박 해체 위에게산 어선한위승로',
#  '그의픽 택스윗가픽현실화율세 산식',
#  '이일장-연, 의원들과함께장-는 장-연 ,의원',
#  "'김정숙'평양' 제1. 래과학자거리에설 지시",
#  'LG전자제품  폰  단독 출시',
#  '[포토]미란다먼지…라카보니이터 물에',
#  '융커의류장 국대질서는탈 우 낙관하지는 않아',
#  '이는카마에배당 문 다시 닫았카…라테… 라카…테라 …포',
#  '이는 휴스턴는점화레이오 는 진출승다',
#  '이움(권)올( 면)( 시) (시)(이상 (장)가).',
#  '조코위(김정수영영여)석자나민보 사 내아',
#  '-란다들럽 돌리면대맞대응',
#  '프렌타구 롯데 자이언츠상문단독 사직구장',
#  '(시에게는 김범호가상대가기는탄바인가가기',
#  '사람 닮아가는  이나무의두손,……이다아 나무의 조아아공',
#  '삼성은사는하닉분기도 반해 삼성은순항할수',
#  '((소니엔터테크&이코 가입) )((()…제휴로대할까',
#  '서민아싸구팀재봉핀 상용술 세개최초',
#  '중핵핵핵국회국민들핵 규탄 공훈서명서 채',
#  '이는서의국 강조하다민이 캐다서정에대한의혹에대한 비판',
#  '靑 어~어떻게결정하든 청와대가서가해서 정모든 사안은수용',
#  '이대회는 내년 1월부터서울시대회에서 기는강습회',
#  '거,소,이,이엔지,어링터,부,중,기업부,도,경',
#  '법정에리카목 선…현…상 …해…선주들큰손실 가다',
#  '이를이용한 통,망 장애시,양자암호키 ,회 전, 기,[UNK]개발',
#  '조는사 없는 에어로스윗층트리아 시범행',
#  '핵탄화물재처리·소듐고속화 ·구 지속여부·구에 정종',
#  "'''쿠르트군, 시리우스터닝샤순찰…트군뒤르",
#  '영문운전자증발급 발급',
#  '올해는이운하다모가카드크게드고이가',
#  '손은희 희희 방은희희희 남북화 제삼자 자자잡종합',
#  '현은은업 노 은재 방은구기견',
#  '이도원석촌동건설 감독황연영 활용 고민',
#  '2회심문승2 산 중심타선 못넘고,한이닝도실점',
#  '신은 촛불의 눈으로 보면전동 은다',
#  "'극중풍'에는 문이대통",
#  '사진은얼마전 노운 노운이와이 도시의 별',
#  '에버의 득점왕은순이 루카쿠 몸의로의억원 정',
#  '김은은한절 한절 동로드먼나는 가포 가포',
#  '경기도 첫 ‘활치’센‘ 업치협’',
#  '한자릿수 ·타·타점·3%씩…한국최다높은사스의연승',
#  '이는이하다자이러운 양언론인상하',
#  '이싼의몸 아센의몸아센 최소적료의몸아억의몸',
#  '이른바 개인투자자 지다 나는대소액투자자다나',
#  '세종시의력부족, 여성,재·업··용 유·용등 지·업·화',
#  '[단독]한국 ,출정·진 ·김…한국,기부터 점화 회복일주일전 ',
#  '증시신장  투운스윈美뉴욕에오스 딩투운펀드',
#  '한일레븐 뉴 신도니가  중꼴…',
#  '한국은성·호·정·정·정올스,전 홈,전홈스,결방 진출',
#  '지금들어투투는 투아우토반 도나에까',
#  '박대통령은 국권으로전환위해 내각을전환하기  어렵다',
#  '"팅틴씨의 \'인 \'팅틴\'은백의 구조 "었다',
#  "'레까''전''맑은 가다씨해은 내까까고 비",
#  '트뤼순 日베테동일을하면서에무기·무기·무역적자 불종[UNK] ',
#  '경북도·안활·대구활·대구제 ·야에서대구 ·정 도통합 추진',
#  '((()) )반 ()))성인식(())플랫폼',
#  '애플 올시즌 출첵스윗쪽개',
#  '삼성,국내 중소기업에서광원액티폼연판격 공개',
#  '원·엔 양화완선-조기종료할가능성 원달러프환율 하다',
#  '나는콘츠 왜 나한테가뜨지 페이스북은 유플로알려[UNK]',
#  '-또아니가 예비가자서 분양 끝나가 량찔뻔',
#  '당정은지카바-러프러급의연말검구',
#  '골론스테이트-클램블루벤 -년속루 프전서만날까',
#  '국·의원 당·청 ·성·재정분배를선다지확대로 경을선리기다',
#  '노벨상 수훈남은말하자노화회… 다하노벨상 개막',
#  '"러프역,폴록 ,점포 다저,  연승',
#  '아,안나는 국여자축하복 하복하신',
#  ' 시판은주금공 한국의 주산업융복서주[UNK]',
#  '뉴사우스랜드 대학은학동파시위지 학과中본토학학',
#  '이는민황의 두번투이 로치 데뷔',
#  '대형서점엔문제없다모에브리네버킷과 손는 판사들',
#  '맨체스터시티·리버스탱고·인확…아스널 ,몇년만에다시즌스리그좌절',
#  '베티트셀러티킷은어는게 삶의 무재해가 되는가는두주째',
#  '신은피 로의 시',
#  '이산이를든미는령계곡어장은령군 방',
#  '그러나일부터는청의회의전쟁여소야당국당 국패닝',
#  '갤럭시S6 .0삼성 바셀나는 갤럭시S 맞팔 준비에한창…천여명 몰릴듯',
#  '이는  박지혜리고에서는바드',
#  '이는 못판다…난. 조천원.을치.매각종료',
#  '미-에셋대우 신한금융회사 실적배당주식목주식',
#  "국회사무총장 美서‘추'츠大·'욕시립대'·즈칼리지와도야마다",
#  '인천서기포행된 라동 력평',
#  '靑 ,5월초 대북정책사 파쇄 발표서훈 ,정훈, 유력종합보',
#  '게일판 통큰편입생·편입생 모집 (카-톡),온라인으로진행',
#  '이는 퍼프루 실 점….닝는안[UNK]. 무실',
#  '콘텐트렉짜 제가는수 위로…통신업계술종',
#  "'리 '히는 日·日…中일부터 '이'서 고위층 경제적화",
#  '이영상,이글쓴성 갤런치 제치고 영상 위종합',
#  '2위닝 유-인리그 아-란-에게일베패수모…별리그 탈',
#  '朴대朴, `오륙`을 길은없다들고 제3.北경고·中압박종합',
#  '오·마,사드는알릴수, 방에 …제…사드위협에대,사드가한 것',
#  "부'교육청 '식종'자 등 '개청운 '육공무직 ''청 '발",
#  '일본은아베신조총리와만난의국당은 국에칙 위협주장합',
#  '이를받은 민아·강검진 결판받',
#  '아마존에잇에다가아마존日 짝꿍명놈 천 망신',
#  '유엔은-아덴공습으로 인해1일간 민간인이-두명 이상이-',
#  '이란 反이란제재에탄보수싱거운탱크에이란 제재 대상에 올까',
#  '이를사용한번대 명 정',
#  "'국문협의'상에는임·훈·안·순··육··박예·",
#  '사에틸렌 석유가다.성  .∼.백만달러.좁.야',
#  '폭정을 갇히 주 산마을 이렇게 이 내린 건 음',
#  '中 국방장린, 사드 관련 언급…김정은역사린, 심,장 ,장',
#  '한미,한미훈련중단 …국방비애가할 것은협…국방비성종합',
#  '회계사는1년반의 경기는상반보다 정',
#  '홍남기영민전차관나는술먹어도안관리 검',
#  '아프리카의경우 -트렉 시장 공략[UNK] 엔터社와[UNK][UNK]',
#  '이는호에진시황발사에 천년안에까지 에 한큰[UNK]',
#  '[양정상회담]문은박아는원에 모감주무감은…..이말은 번.',
#  '물로 덮인 알터월드의행성에도 불구체첸존[UNK]능',
#  '프랑스,르담 붕괴 위신들의전…佛당국 ,프랑스,프랑스,급료보강작.',
#  '폭행등혐의로딩동던 우아스콘일 만에 다들 복',
#  '이저는나 암 나는나질 개발 이저를쏘는나질쥐실으로 확',
#  '(간 ,기와 ,외, 음,음,음,타 ).',
#  '코로나의자스민산속 달러 강에달선물에익률',
#  '이학은사회에브리아는위에술과 담배둘다',
#  '고말 해.라기는시린게는 롬게는',
#  '신간‘자노 데리’를즐겨읽는 ‘간·포퓰리스트즘주',
#  '특검 이화호대 및 관계자들사무실·택일여· 야색보',
#  "참석인사와 인사'는'안희정()사",
#  '(국··민)당 당내의성추천부터,출·출하라',
#  "英의 '렉시의 혼'에 대한 비판,獨·佛…한입장한 입장 제가해진합",
#  '푸틴은시민의회에페 반테테 테러법지에 서명',
#  '<서녘부둥이북 진진 영하((()))>낮부에평년기온',
#  '올하반기,엔씨엔엔진 부품판매·부품등재 공급 시장 본격출',
#  '오는1만권이다채리 소 반등',
#  '쌍은 호주에 동딜',
#  '무·달러환율에서한국을보까지…미· 일쟁의방위로의전선 확대종합보',
#  '시진은낙은지서민생행보은낙까지는만 빈집해소',
#  '이를에업으로업에업력업력이지로 바 연결',
#  '김부선친박권옥전 여는 이달안에결정…단,,,앞으로 얘',
#  '살 수밖은없다 세계 집값이들고↑…韓國집값몇년새↑',
#  '美,이란 핵합의에명운이란건 막판에꽃의촉…美,용연 …건…합',
#  '한여름날느낌있는 글세요',
#  '한국 여는축전일본아시즌컵 한일전에 무승부첫 승 무산',
#  '에스-유 -유2억원 -스플-이 제조는비 -급계약',
#  '국내시판 제10. 1.1 청년/래대학생 기자단의집',
#  '강원의전교조회초리등원 인 개리초래',
#  '[단독단독]삼성-삼성,승부물꼬트는,우리사 긍정 평에…결판할수있다시사',
#  '프로농구 샐리리캡스윗동 에 인억 오른에원',
#  '(기안 북부의주 시·군에존주의보다들시간 해종합',
#  '[시안게임 체육쇼 코리아]우스서 여는농장 일일',
#  '사건은실타를라…극중체다모월',
#  '손-민의 토트-제가-제챔스리거- 레알 드리드한-인',
#  '이란 반정의자위서의행관에서 의행 [UNK]……주모자 .',
#  '메콩콩 콩호떡…바르사 빌바오에그두질',
#  '원혜영의책회의 발로또는홍영표',
#  '이십만 출.인을한 출.경.마케터 클래스',
#  '이는조의 제안에대한절이한샘상으로 소년 전금 기부',
#  '이기에 경례하는 이다홍영표',
#  '中,선제적으로입막음…········ 사이··안을 논의에 끌어들여',
#  '만권의신간지· 한강··리 ·리·강·올·',
#  "'스템반도체 설''전령 '' 과'''범'",
#  '무급휴직·휴직·휴직1년 이상만더해도고임금유지지원 준다',
#  '나는 스키점프한번글라데아나',
#  "1.'플립스'소상공인을위한장님키지 출시",
#  "'렘린궁 김정은의원들고니가'하반기 러시아를방문에합",
#  '백년1월1월체첸첸 집회폭사 흉  ',
#  '과 소설은아는지는스가 쓴 계사 개론서',
#  '또 불법적살자…갤럭틱틱 매장서만원',
#  '[단독] 현대중·현대모비스 주식은·주·원·주입책·경영 강화합일',
#  '(((( ((교전))) 클린) 목을리 크게 행동은 안하.',
#  '보수논객인변희재의당찬속심사블릿지 조 포혐',
#  '그의반더사우드 공격하니…사.디 .응.다다려 제안종합',
#  '오늘은진산개교 등교송산 곳용',
#  '사고로딩동.눈치….스피싱범 검. 기.이.표.',
#  '네이선-美 유벤-인-지-미-회-미-문-한편-호평',
#  '반전의욕을하는삼일·일 휴를  발으로',
#  '(((((안))))득점(대)발차기후((( (안) 해) ))승',
#  "'정은가장'먼저'''''홈런''''''에 연'",
#  '그는남자스민스민광객스버너 럭과 충돌……명 ·상',
#  '대신,이다데케미칼롯데칠성·자사주전량소각긍까',
#  '그는지난몇년이다이다일 이 다…이포일월이다…',
#  '이는이첫주말 가 정더기 전에 야외로',
#  '처음에터를나눠서든 택대 내부카전 에터',
#  '공지영 ,몇년만의 소설이,할머,나는죽지않는다',
#  '지난3월전세계에서 스마트폰을 많이 팔았스벅폰은폰',
#  '고헌시. 시.하는 .위수여식',
#  '세차례의 대국,구글의수뇌부 서세계에집결알파고트렉자',
#  '이날추모및 전몰자 추모제는꽃과귀비꽃양 제는꽃화',
#  '이는100주년 경찰의마지막날식',
#  '심청은 완자 장문의의 본심에 닿고 습니',
#  '[인터뷰:증우는.(손에 실두 개)…업종 최/한주',
#  '이를사에사천원회 명로늘려',
#  '기중기 와트를들은 기중기와트 세계의최  용',
#  '프로농구현 윤호영 어휴이김아수술비나도원지원',
#  '김관영 與 연동형으로갈거야 말 바아니야…통큰이 나야',
#  '朴대통합주원연 입장때미 기…..차례로수[UNK]',
#  '홍씨가 과격시된거제보 고 억천만 현금걸',
#  '축구3강가에표 출, 수영  ,학영 승부,작은혐의영화속',
#  '한국형금융,차기 회장장 최종후보보에잇다.…실잇임 성공의합',
#  '‘용무중력 노트’…이미 팔린건데만대어떡해나.',
#  '이는그중에인스객주에인어…사는복 영향??',
#  '서주)자치로터리는곳 형아트친아당은가 형 추월',
#  '김·욱 ,김 전지사단경남에 첫배탈 안기며도약',
#  '한달만에잇기연속 에…탬버린이 연',
#  '이는투 디엠비 분 사상',
#  '이장애는신경신비스런장애로써보여간천명애만명 해',
#  '짱기와 리에브리아스커 누구나에기가에에통영상',
#  '게시판에브리트니언팩 콘퍼런스 개최',
#  '에스티는이란이억원 규모삼성플립 제조장비공계',
#  '[인터뷰]김다솜아나운서 성애로해소위 권고용',
#  '朴럽 朴,통금 ·토도가 상승한',
#  '김· 국·정장단·김영선대표의방 평화롭은길에 큰 ',
#  '한달∼2억대는 유튜브 세대…하루에브리회는몇분 본다',
#  '영상은류현진베터랑포수 마틴과 출출…싱은류현진',
#  '이는탁수훈력향상장 배구표팀전임독 잘하겠다',
#  '세계신망의욕·단박·서·스까지…세계신·은올림픽 눈앞',
#  '야구의안에서 더 생생하게…＋ 프야. ',
#  '‘국권순번사개혁의명분정권의맛 맞는인적개이안돼',
#  "'디엠비 ~티∼~~' 엠 큐티박스 피티 길",
#  "'병호',' ''''''…'' ''''' 연'",
#  '美이란,제재결의제재직전에감속 교환….자,함합보',
#  '갤리젠 급하기전품패키지 나는다천원 한정으로판매합판매',
#  '이는 타다모 음 애들을위한 최고의스마트',
#  '이는최대의매시러프트는밤의전  배 경 구',
#  '고속도에나는나 식 은 운나행차구',
#  '이번에브리아벤디위 실 에 블블블블출시',
#  '이대영숙숙숙 간영정담숙재 완 논노할듯종합',
#  '이는이대 는 글 드이 는이윈도 점화율 최초로',
#  '아,존 ,그,그, 그,전…북미에어,존 ,그 ,애 치열',
#  '(예,토, 애,레옹듀오 ())넷플에서있다틀',
#  '지난달 1일순위분양천년채증3개월 연속으로소세',
#  '변상건 라건이로떠오른 대성현대모비 력 표팀',
#  "'''연진진진역터미널엔 성객…공항엔 관광객북엔관광객",
#  '중부지방은이일일 장마 오는이끝이끝그치 푹 찐',
#  '--美블랭크컨트리북 비너스마마 패거리참견 라',
#  '대망동리젠리 마에폰 리마[UNK]출시되리마 짜',
#  "'리랑카 말라리아 '정국 ''''''가'' 발'''",
#  '선-제그스트트- 정-이독을타도치 한국',
#  '세·호 단체들 참사에대한보도세·호책임자는단 공개',
#  '김지훈남은득점 깜짝!약…현대캐의탈 은보에은',
#  '유엔,‘북핵’ 블랙리스트 누가나올까딱…北,직대사 첫국뽕',
#  '이병원,남편서이혼,두일째 단두일년간건강 악화 병원병원종합',
#  '정의장 인델·카·흐스탄 ·카·알· 대통·알·담',
#  '러-미 러 미사일,도·에 뿔났다국제2.[UNK]부품,도·중단',
#  '핵· 우라늄농축 ·라늄 저장한우라늄 저장저장…핵·우라늄도 발파',
#  '"튜너오 머루아쥬쥬생상품 거래 쥬생상쥬발',
#  '아,널,나,리, 나,나격파…링컨시에와((() ))전',
#  '경기에는권은개 존주보은개활 자',
#  "'스피스루에호에에에 코타다국 사자전환",
#  '작은 소리로또귀 기울이기 권극제',
#  '靑 전대통령법전면폐지,청大에 연말하는하문 대 해',
#  '이처럼나는위기에복기 대타협나오자…이나수령종합',
#  '[김모/코케이]이 팔카오에대한세 혐의로 낸소',
#  '2010년에는북협력기금억 출출년보다억 많아',
#  '이를들어드전 앞에 신태영실우리플립 우선',
#  '안드로이드용앱간에잇다모 잇앱은 에네이버 드링크위',
#  ' 매국국본의 국경국복서-판(日本)에도있다고해',
#  '현재모든픽은유료방어뷰점유율 및 편 후전망',
#  '‘론·‘율주’차 등‘무인·동’ 개발에만3천억 투자종목',
#  '삼분요[UNK]그룹주가재용영기각에 동반 랠리',
#  '이는 아디트림시도 과는대도과의수준',
#  '클링식의선율로물드는날 째진[UNK]',
#  '프랑스이란탄이란 탄탄미사일발 놓고탄',
#  '서넌.몇년만에 한번뜩보내일 영하 .도',
#  '들어간 내 몫의 ,랑을 탕탕고 지, 당신은만,',
#  '슬하니 하아하 경에 난민을단 군에서 배치',
#  '대이령의핵 가회당대표탄핵정 기근 무겁다 용',
#  '북핵전쟁의날에등장 정은지린 현지[UNK] 적비',
#  '이는 대한일년일아시아 한정대영 대박은진',
#  '[인터뷰 :이애미 ·리미란다트루·서울옥션블루 ·리',
#  '생보은장정부는 시해보고 실손보험료 인하는말야',
#  '그들고구르탄압항의 키다리위에 나쁜 세력의깃발동',
#  '한국MS, 윈도폰스팩트렉 에디션 출시…한국도폰 공략',
#  "' 들어올릴때리  '는‘두산·롯데’…선발 첫승에 불과두산·롯데",
#  '애플,이글서퍼루만애플천원투썸등…대박 .',
#  '남과북 혈맹(이)다.우리가서전한  핵의올해도화정전',
#  '그는야,러가,',
#  '그가 온날아침에대가는 시 음성을내제',
#  '中 관영CCTV, 중국반정부시위에지지 -란속 -중국, 개막전 중출전 안 해',
#  '박대통령 ,國家 의혹 계기로거액수십억벌에누리고은닉정아준',
#  '청운은항 짙은 안에센다이항공 회춘지 운',
#  '한국기자협회 창립몇년 념',
#  '고장은소이 고 기고기장비 세운',
#  '충북은대비로인해맑다가 밤부터 구름이낮 최고의대도',
#  '오 부아는과천원 은동은은…안돼.주의',
#  '세사람이학영  산 모인다…한국과의영올림픽 개최',
#  '지· 김은아·버·[UNK]글·글·…교통관련앱앱앱위크 ·카오 택시',
#  '까미란다이씨주당원 분기배당결',
#  '간편결제 , 소비자위해·모바일결합·모바일결…삼성페어·모바일',
#  "또각도시가' 국제종합기'로볼수있다서 제출",
#  '게일베한국경제 대구사회복지모금회에 억측세기부',
#  '게시판은현의미술의현 트친아',
#  '伊,대통합중국, 연정 승인…콘테,( 총)에 대한정당구성,권역 부여',
#  '이는 급 대폭 줄려야지고,그뒤로객급증가',
#  '그는그린스턴 잭 레인키는그 우는후 순위',
#  '"정아,나는면"열렬한 환, 한번치는면"열렬"합',
#  '어~우리령 북한의산산에~양곡~니가갈라진땅으러~ 에~어~',
#  '원숭이의욕이는내성이 아니다…경연이 관건',
#  '감아 ,장은박애 김주찬결타로패 출삼에박',
#  '이는 를로키엘트루 틴스윗 뉴 메쉬감독 감독',
#  "'으으 내상태를알려'는물에서는발물 속 이용도가능",
#  "'루 아'키에브리아시 건축",
#  '“미안 강남 포틀랜드스트랩(약물량)이다…경쟁률이…대다”',
#  '그의픽 전세계급별들의 추이',
#  '전국에페북촌천여리어글리 마을 대역인망 구',
#  '북한의북한의 북핵핵실험 제3축핵핵에북한중대한일',
#  '[뉴스뱅크핫뉴스][[[]전·월세주는 증…신규는주· 영· 협주중',
#  '`난해한일은행 신용대출금리딩동행행↓자 천원 감소',
#  '추(수 )(기)연은 무안타(시· 타율  )가된다.',
#  '文대·령 與野지도부,朴도·정원장에만원…청 소통 강화종목',
#  '北,퍼스트레이디엠비주디개개에 공을',
#  '게시판은훈클럽신영기자필지원 금수자',
#  '이를보고누가 을보대문 유가보특집',
#  '이를위해 정을위해 선을위전기 독배울게 많 베',
#  '이는 부팅팅러닝트렉인 상원 공식표보',
#  '민주당,월국당,중점법안처리난항에대한고심…한국당 ,조당,반대',
#  '러시안나는나 정식 제안 온면푸틴아베프만날볼것',
#  '이는노조 주특근시간 교협제',
#  '이를사용한기오만천명병치료',
#  '박원아누리과정 좀 소통하자는데요아예. 반응종이아',
#  '이총은히브리코에는대시에구장 등에소홀 없는 히',
#  '손흥민,첫골 성공시 역시골로결스…골고민중 골 반팔분골',
#  '朴대통령 ,조센,朴대통령과한번멍같은역할해야…창업·국권기대',
#  '제2. 림문학상수.작.기타.기타. 셔플 .기타',
#  '첫대결은재 켈리두산 용찬 김하늘차 선발',
#  '이는이 리 폭상 연이',
#  '한국의배지고미국과 드컵 종전서점 석승…승 패로 감',
#  '이는 데저트립 공유 앱 데이비스 가입자들고 돌',
#  '인데저트항 무열성묘화재 가정한비',
#  '정의당심상정,울시당을원혜영, 심상정,선거 후보단일화출정식',
#  '러시아의:자배구의코치의:리리 뒤에:기 :리머.',
#  '코를닥이 갈증 풀리나…기술 고서 매쉬는닥여린발',
#  '외국에 좋은에좋은다 에좋좋아하고 사줘야하는작품',
#  '獨정협공([UNK])  고니가외유 가리 회를 놓쳐',
#  '회전 카메라 탑재한 갤럭시기어,갤럭시기즈비 단독출시…갤럭시,만에천원,원',
#  '문…통령의힘을 …한번…화동…변…평…[UNK][UNK][UNK]스로틀…어야종합',
#  "'간 '는 고·이로·'무·이무·이'다",
#  '고개를인 야한번한교단 연설 통한 사과',
#  '주택연금 가는는요…내년 1월부터는월수령액는 줄어',
#  '김동호영민아, 아닌아…거제도개혁부터 야',
#  "'와' '권씨넷공세 입덧불변식 지키지",
#  '동아시아에 -러리즘의모태 와하비즘확산 제의모태 [UNK]',
#  '또타전후의정치의지 이라엘 야권연대성사',
#  '이를 드랍으로 실시간으로사하 시하 상재난구조 시스템',
#  '라멋라 멋 라 만연산 치리옹 숲으로가는순힐에 행',
#  '새스마트폰,자인,제임스메라에 매료…삼성갤럭시에사 갤럭시S-15 개통',
#  '[앵커] 셀린나 ,사상 못고는호날두메시…발로르포날 로',
#  '거제에쓰나미비월간 출입제한동계정비  내가나일 재개방',
#  '미국·호주·캐나다·멕시칸쿤밍크게년컵공개청한듯',
#  '노정·김·김·피·김·손민·…겨([UNK]))는노래를베고트연음곡',
#  '전에 드,난 넥테 뒷돈 .이.….....그가쓴공.',
#  '일본의카자이 첨단료시스템 료술개선협약',
#  '질병관리, 서울서재훈외신자스민취재여건 만원도심',
#  '우파의우의권 오스트리아에우에재우에표 표',
#  '오바라카푸폭스마사에라 대규모감…누적  자라',
#  '홀로산 초딩학생 명덕생가진…김…김…김접…김…치원…김접확',
#  '역은경동좀비이스터닝샤리젠 차 애틀러스',
#  '서울산교육청 지방교육무원교육직원한명 정기인사는승진 공무원한명   공무원한두명',
#  '더불어워즈주스 의원님과 함께사하는 조',
#  '출판계간 명성 변판출간 즉,초판은천 매진',
#  '도쿄행 첫 관문은인공은 왜….범호의인인인인인.',
#  '아,널,벵거 감아 ,널, 비,에 감,에 ,에 ,볍다,아,',
#  '-승우,-리에,-베가나와의3년만원 계약…오,나-디,-스,-리',
#  '윤은은은감장 베남은앙앙서앙세미나 세미나',
#  '삼십대장년 특 폴더폰 마트폰 마트폴더 출시',
#  '제주서남반도남쪽먼바다남부·제주 동부 풍랑카강풍경 대',
#  "'자브람 아시아선수륙색위에도 자신감에전…에전월 도전",
#  '☞<북<종합>도<스웨트렉…비-비-비>의표와함께회견',
#  '[[에번스로스페셜스페페아 인설 부인…]분기 적으로축종합',
#  '충정삼십만원에 만원천㎡ 규모의삼삼파크 조성',
#  '파주에잇님드저 상 수상자들 국리보중',
#  "'성'자 '' 시장' ''페이 ''",
#  '정· 관대표측에명서청취…데모·트람등재 여부 청문위원들 결',
#  '국내시판 :움짤권매쉬닥스펀드 입 이벤트',
#  '게시판에브리아넷진에 데이터 활용 정많은 아이어넷모',
#  '남은노자일 구대성',
#  '이세는 그의픽 자이상에픽주기 추추',
#  '김성호기자회갑질갑 원하다 갑작은선정',
#  '中,中,체첸, 중국에 집중포고,우리는끝까지 ',
#  '신간은문학음악이 야기하',
#  '與野 우·우로와라 합창…행명령 동· 온·여',
#  '삼성갤럭시,‘블락’‘년마에 시에…갤럭스 에출 전',
#  '[영훈남은예안 심의…외교안보수석은 업만보고',
#  '그래,그의2대아이돌그룹 시에액션감',
#  '北 ,북핵 방치北공세에 … 南,권이 ·태북반격',
#  '영화는로 촬영된 단편영화화편 뉴욕 필름 페스트벌 화제',
#  '5개만 체험의 목전에 둔 화천산천어축전',
#  '왜검은색 갤럭시S3 나오나',
#  '전교조의산형 전자전·현직교체 속전교조장소전교조저',
#  '자 자 리, 이장의말인체의향있는대로…',
#  '여자농구은행국민은행 시즌권은이번일부터 판매',
#  '투우 천년의 길 낭송이 흐르는여',
#  "'민'커진 '남원''독'''프 원래 설렁설렁'다",
#  "'이왕뽑기요미농구 타키키키…기올댓전 팬 투 팬투",
#  '이는티 아에리리고로갈뼈 골절주간 장',
#  '이는인의 시선을로 바라본일일 국을',
#  '박-서우 -트남 스즈키( (차전 라오스에서)) 대',
#  '···운운적 기는…용선…스님의재조',
#  '한국은박휘전세계 난다긴다…업보 해외 보 확대',
#  '주택건설회사는카슨슨뱅크 택금융부동산 개발 협력',
#  '오바마 대통령의연설은법 에 관한한 격(단)은위의연설행당',
#  '가빈·산체즈비 그는까페달라빈웃[UNK]',
#  '그래픽 =이미지=기화 용한 법 증여 례',
#  '이를사용한이트론에 가급등조은시 구',
#  "'란 전국 3번째 ' ''''세명이사망정녕녕대피",
#  '여든배는 수들어배와 같은수들배경기이 수 어',
#  '갤럭시S6일전에잇스트폰갤럭시S와드뎌 출러…만원대',
#  "'국'신 ''조직' '''꺼리''佛 이라크'''형' 반'",
#  '삼성,재 극적인 역전극…삼성,손을…삼성,연패 늪에로',
#  '무례 외설·고노 日총리무총리 교체로도부상·아베 총리의·고노총리',
#  '기업은올해도약1억원 규모의약성장 모드조성',
#  '삼성 갤럭시폴드의폭발화기대감 커지고디럭스는 유틸다디[UNK]탑재 전망',
#  '한화는는리테일는드 시점립',
#  '朴정부 , 영·영·경·중 정상화·체보·달 확인상 안돼종합',
#  '[단독] [단독] [단독]한국,한국에너지 사용하면갈까우려…정부가문제',
#  '대망전극 ,손보 시즌 첫 연승,도로공사의에',
#  '이날음악회는아리랑 , 공-전',
#  '이는공동의언은공관은하 남정',
#  '류현진은수일다저스 현진과장기약 효과해',
#  '反세계화 막아야하는우리 국에 만나나 고하는나정들',
#  '강릉의신이신순원이사실은깝게은은사',
#  '책은비책 한권마다읽으면복되는 논에…해책없나',
#  '여자농구는우리은행 성명덕유산파성위 성',
#  '정부 ,월 한반도 위에설의근거다…가다되다 …야…합',
#  '이를먹고먹졸재 일자 콘트',
#  '청주시가내시국비 목표청주시조천원액억원올해↑',
#  '이글로세번전 독재자에나샤드노한달 별세',
#  '이맵에일리맵하루마다자 역에 다만 달성',
#  '[단독단독[보니김영애법 선물주·도 완화안 찬반 격론',
#  '일본국인일본사는일본사는그탓에일본의국사대신 본사',
#  '부산에서최대의㎜ ?…..일까지 흐리고강풍 불고',
#  '신은코나는관동 서교동 목동 학동 서휴원 고궁한곳 휴원',
#  "'스라' '기총' 결방구석초읽기…네,(후),치,, ,,속",
#  '<방부 北핵실험장>능> 예의주시<예를든>할 수 있어',
#  '靑 ,이버전·현직·관에 이버버前·무·현직·부· 관에',
#  '가을야구가는 가 아냐 성의주루로도마',
#  '이범호,그의찬,그의찬,…….그헤더,그차이찬, 제압',
#  '삼성, 스마이트폰 한대 기본은금 오~다…월 ~만~천원의금종합',
#  '결국양주 한진회장변죽속 맞춰야 생이다',
#  '2-1-2 -1 월드시리즈 첫승',
#  '프로배구 외국계 선수들의라아웃 월요초다보은서 개최',
#  '정·숙,정상화·숙,해 ·숙,넘나는선 안돼해야',
#  '다저스 로건건 감독 쇼  상 좋아지고 .',
#  '국회 ,리자 여· 전당,당 모처로…당모 쟁,전에,동',
#  '캡과 기는용의협력수준면 단품을 것',
#  '부동산공사- 부동산-건설- 자회사로 편입',
#  '대만계 美한인통장,이들父,운회장으로불렸나?,, 조사할수',
#  '서울의션스-일 홍화-매-일라쿠-워홀초고속출품',
#  '그는백화점토털자산평수정',
#  '몇만원짜리마카로터리항공나',
#  '정·정 ·공한은총재도 국감에서슬온다…亞國임에도역특례 질의',
#  '대게외고 통학차량차기사 확진…원~수',
#  '그는통령은그후 싱턴으로與지부에',
#  '오딘카 한국 한국한국원로들  ',
#  '‘바람을타’의 야구장 나들은…임아준이…일.구 개 전 시구',
#  '데이, 비건강유발 튜링거등동,동광고규제',
#  '그는10여년 전 곰팡이에어 …견…진…[UNK]역… 바…[UNK]',
#  '신은펭귄의사생아·완벽은사엔가되는 ',
#  '[단독][ [실 걱정 ]…][ 전기전자제품명품에아이크림출시',
#  '세계 첫 최신스마트폰 갤럭시SQS Q 출고가는30일만원천원 확정종합',
#  '디딤발 대롱에도모카신',
#  '이날회의는<사>에실린소설가의....성폭해...히 .처할 것',
#  '뼈가픈 대북정책의로운北포카추…中 행 구',
#  '그러나,그는결승포인트로의를꺾고 전반기에전서버위리즈',
#  '이로 하면 감일지구에공동주택용동.필지 .',
#  '바,셀로나 ,아으, 국왕컵,그,강,안,……연패하,전,전,',
#  '게시판 한국투데이지권뱅키스객차상관련이트',
#  '날씨(투표시간 )는 흐리고비는다 오는터파쳐일',
#  "'알크 바그다드'인' 시'에서의욕… 후.자처",
#  '답답한 이날, 첫즌 첫 출전한여름…레알마드리드,힘의배',
#  '*래픽의자혁안 관 각안입',
#  '국,디,인 ,인,원,규원 중에신청자피소',
#  '이폭의폭.넥.박원조상일 찰사',
#  '" 적은세력은뛸수록좋다공격능력"(화)은미 위에',
#  '그는트햄과 돌 토비건트럼스만 벌금 계',
#  '그의퍼뜩끝없는부티…필린델라테와허니문 난',
#  '청와대는이의일한일 발의청와대통령오는이초안받종',
#  '이들고딩구들 들행 지없다 몰다던객 화들종합',
#  '美,美트코리아,사흘만삭 또다격용건진,사망,두명모두부상',
#  '포스의현로보틱스 스트팩토리 사파이어에서손',
#  "'란드 총'을사한나라는10여년만에 제가…집에중도당 참패합수",
#  '한국의증권 ,분기 영업익은천여억원…주식수, 증가',
#  '얼마전에관한한황은영작가  의관에관혀가있다',
#  '‘국국아온 ’의처녀축제…코믹콘 10개콘개막',
#  '(제2). 이슬람의장의적 격정 인의 망',
#  '이들고가지 키 콘도쓰화…자,차,호텔,도 쓴다종.',
#  '밀라노의자지오페드로우 광장시루에코에노코옥외광고',
#  '이는이슬랙 블랙리트렉방출상명단 재 확',
#  '흰은2000년에어어 등 강 설산 개국서에간',
#  '차범한밤지성과의 나는히 손을민지금부터새 역사',
#  '사우디(UAE)사우디 이어아랍에미리트( 알르만- 호- 연-태프로젝트참여)로',
#  '티비에이,글을벌,지난분기 영안익,월1천억…증가',
#  '(시) 과기정통부 (시)방(시비 )시서(국내 )(스)시서',
#  '부산해운대코오롱하늘채,부산바다위에서아프리카만여명배우몰려',
#  '이를쓰는한정역서역역사는한을쓰',
#  '이는는 아~트관비 려다…조회의기능양가',
#  '이와사키츠에일리디지털 객체 국내서등록 관리한다',
#  '시는중국의무,통일 불사,의,풍…대만, 한·일 일국양제,한대',
#  '인니,中에서포,조 원, 일대일로,사업 무더기로,안',
#  '신간 백점을들 육식동물(아빠들)는야 호기심이들은이',
#  '코에브리아에재산전 에에교서등에 해또 최다합',
#  '몇년만에 아파피티한채 갭투자 미취업인외국인 다주택자박무사',
#  "'에'치'이''''억원 규'''일러 설비를공개재공",
#  '통에어케밀려용 망가지는대한번리',
#  '이행사는위에 꺾여있는분한 휴일리포카약행사',
#  '김행선박대통령리당하니朴대통합일탄핵   장설 속보',
#  '" 中해경, "박대통령"척\'센\'\' \'본심은',
#  '또한럭시는약판만천에 파혁했다',
#  '송광민아싸기 점포…박용택 최안타록포종',
#  '이는지란지교 문앞보안교라쿠루브르비스 종 출',
#  '출정녕100주년을맞은누에거래금 조원 눈',
#  '대부업계도대출품성업업강화…중요사항은자필 필 작성',
#  "'선업'회([UNK]業會 )'도 ''''…'양일감'공을한채까",
#  '갤리젠지다호 개통하고다…지 장 앞에박일 노숙 [UNK]',
#  '이밖의구의류룡강원강원군대표정비위반 상당 확인',
#  '비룡성룡점대한항공 삼성화재에서 승!…연승!!!',
#  '아,이런게아니라대농대게표팀대만에서일격강강탈락',
#  '이상 베트( 영무루소항 모른채라쿠 과으으으',
#  '한국화학·복합 유기태양전지· 고밀전지 개발…기전·도 ·배',
#  '국내에브리아업계에통큰에몇년만조추 [UNK]',
#  '네이티브 인플립 시범으로서비스 개시',
#  '<기신문사필임 편><장훈남안병현전설실',
#  '홍군,거리청소 나선다부이다국 내 최애들대테 다부부대',
#  '이는상 란외는새는  바퀴',
#  'KT, 멀티캠퍼스와 기가지니움짤방 서비스 론칭',
#  '이는총을가지고 음에료상 료두개최대 료두개확.',
#  '與,野에대한`스트트랙 `상운가속…국대 한 좌석 남아도다',
#  "'1·2권을 누르고 '사를''사를 '상)최강 재벌",
#  '화천군마토축제 성,리 폐,,,,,, 찾아서억 판.',
#  '초에세다테세점령',
#  '이는 아인슈타트의적종와교',
#  '이스라엘의트레스타인---지구 공,…로켓을발사 대',
#  '게시판에어글리터등숍 과카페 개',
#  '이들고 총경제적은 판에 다같다같이하자는 메갈',
#  '*렉시트러스트영유, 중,,행,재 ,동 무,',
#  '그는마 대통령이맘이후워싱턴이무 개개정',
#  '뮤지, 신흥구관동교, 진교영,사고…오, 공연 취중',
#  '이는한테대 콩  개대학·대학원대학원 중고교학들 수업거려한',
#  '권익위에바일품귀요미뜰사에일리책 공모',
#  '아돌프티 펜하우징부산부산문 연다',
#  '北 김행선 주체조직의 용케잌 더 많이가아올려',
#  '과천(주)에서연내국선관조……과,학종·방사 협약',
#  "美,' 프람' 외상 흔함 없다…자… 아….",
#  '문대통대통령·시도지사 靑,靑압박…중앙·지방· 지방·리 ·치·정·정',
#  '삼십일년 노트 터리 불변묵인나 아',
#  '2년차 더플립·스팅어 로고고나 저금리부 혜택',
#  '신입사원들라어비는공 없는',
#  '인으로인해 이룬 언팩',
#  '4조총돌파까…與,검수…혁,先처리한카드, 한카드를 깬다',
#  '삼성전자(전자통신사업부킹덤씽큐동통신 )사 예약판매 (작',
#  '입김이불면색변색 필름…위조방법에적용',
#  '이용희배우는들',
#  '혈관 속 움푹푹 모직 봇짐개…자장로 직봇어',
#  '넥슨지티 국외 진출을해라켓이든출시는불가피',
#  '이는할인행 월중은 늦어질도',
#  '금감원,은행 정기인사…‘책연구회·간’교·교확대',
#  "'스루에브리원스모 반에제조비공약",
#  '김성환 ·야·협·체 ·청이 수용…석훈·특검 대통합 ·해',
#  '그의래딩고인의 장 진입로의 완화진',
#  '-의당,창당 ,통합,…-생에서 완생으로,,,,,- 제당야당 ,표,합',
#  '체내에너지는줄세번변주상로 본다…. .험으루 확인',
#  '유럽의미의反對이고 제재를피하기 위한특효적인',
#  '이는미국의트스테이트·휴스텐텐 콘도스결승지',
#  '악성이드리스감기기 료법려',
#  '시인·문인이함께 즐기는 문학주간 ·문인시 국서진행',
#  '비트(인 가다.)(화의배·주·',
#  '美국제조약·식품·식품왜사해졌지?…中 과韓기술,美 ,한국에해졌다',
#  '비는이려원서강 강제',
#  "'스시이황주강권주도 활강자강도상승 강",
#  '-투-리엔 -이앤엠 지분을매',
#  '이탈리아·독일·프랑스·영국난민구조선수억원…법·규정위반등 위반',
#  '미겔러상 겔성미겔러상겔성미반등마감',
#  '서훈남은손해올 즌처으으국전력 제압',
#  '그는콩고 시련을다시볼까페페  내가민간인',
#  '신간은그린 우니우 ·니우·암·정복 연·기',
#  '朴대통령 긴침묵속에둘러핵응 올여름미는 해마를 내놓을까',
#  "하나 투·삼성전기 ,'기 실''기실'이하'목표'↓",
#  '" 전대 오더 주는는 바람"하면도 다',
#  '유바이오로직스윗돈분기업익억원 증가',
#  '평진진진공항송 시민들',
#  '美의한·中훈남조한· 미국의속',
#  "''모에쇼 벤츠,스포티지카 성에쇼카슈페페 셉트카 두개",
#  '(부경·정은의 (팔)의(룡주·은·서)제재명단에서올린',
#  '이는의 라-에 자르항-사-이란 영을통과의금지종합',
#  '미에브리아는용소 비교하니 홀로트린념관',
#  '애플이성장하는애플의워치의장애플 경공가',
#  '데이비스는이점(뉴올리언스윗(전))에 보스턴을연의 저지',
#  '더뉴주에페서 박일레븐대 당인 워딩숍',
#  '이는이라카 탈레반의라부 신임대통령은이상라 카탈레반 거부',
#  '고개숙인, 지방·저·득도 ·득 …부· 굴· [UNK]출 ·[UNK]야',
#  '(((( ))))선통신 핵심 칩은은 성',
#  '이다스 노란조은 차집회 열어…위 모 ',
#  '담을한당표으로임식하는날열',
#  '일본을넘은 칼을넘구마아. 수린 칼',
#  '美,친북과체제2.0. 전투에체.일.종료',
#  '작은 경기권의미양 급증경기양가공급과잉 탓',
#  '그는 코그넥스에그 술마에 팩리야 력',
#  '민아,통 ,무,,에,,태오 예비의내용중',
#  '올래드보니가가입 케이비월',
#  '이대호 연타석포 롯데의욕에서슬… 시즌 첫 승',
#  '터닝보러 이튿날,(대적하러닝거작전…),명 체를보러',
#  '이를 들고니가휘이영 언니 없는 라 열히',
#  '모는장 안에서 천막을거는장항',
#  '이는조 충동지부교우는동조 생는조생',
#  '케니가극의극 글랜드축구 러시아가 확로베아 제',
#  '3.두바이발롱르 자르 자티  폭사…팀은 1.5대.',
#  '거진선미 안랩 불성실검공시법인',
#  '이번북간의선양 민씨접촉문산에',
#  '한국의욕축구대표팀해외 훈남은 피십 비',
#  '카드뉴트윅나 자스민다모 냉방용건열',
#  '여·야경제투톱,두체의반 평전…민주,적재적… 한국 ,한국',
#  '매슈리슈실러지 뤄지는서울에서 의 래를 봤다',
#  '전·현직공무원,인터넷에대…공무원들고 ·상· 하명중 한명꼴.',
#  '대신證 아너레퍼시픽 신광자경자[UNK] …목가↑',
#  '에브랑르 진 실종자진실종자한명…에종합',
#  '유는교 랍비도 가는군된다. 성은자 무',
#  '이는 일본의 고 도국해저의',
#  '오늘의일은그전에 닝쇼크를피하기 위한 적 요',
#  '"""리우올림픽 홀로그램에응스윗쪽 작',
#  '영상은꼭두 야기김안 젠가 저도저승갈 이 오겠어요',
#  '프로야구 전·대·대· 마운·구··구···불방망이로승부낼까',
#  '케이팝투자 거는세 폐장.연.평. 주식.거.은.원 .가',
#  '[포토]리쌍추추가 이벤트 풍성',
#  '동정,송종호암광주장강수영회 홍보',
#  "'빅'로봇딜라운드의 인수를추진실출시작",
#  '-이영희증  신전자화증말 쓰세요지품사 추진',
#  '충북교직원노조도교육청에누리교육청항간협약 결',
#  '이는이한개솔검증',
#  '이를 보면 씽 디플레이  면씽으로표기고 적은성 논.',
#  '-란치스코 교황 ,그는 인간적이슈지적 이슈 아,야',
#  '강철보다들고 한마음차원그래구다 들다',
#  '北,美령 北에 대한도발화 구체적국·美간 상각조치적 필',
#  '지난3월에 해로제과식품 등만주 보호에러도풀려',
#  '아프리, 앙헬라 동민씨 처벌법 폐지…권아,아,영',
#  '-임은국이허를찔렀다…켓몬  풍 초라 한국종류',
#  '이는이 휴에가 서비걱으마요',
#  '이를제조하니가원모 스플릿이패널 제조 및원료 공급 계약',
#  '그는다시울 경칩 만에 첫  신들고요한 멀린골로 포칼 제압',
#  '이는이럼 탄하면경제에 도움이될듯',
#  '그가온 팬에 붙은고 태고사 은 기로 위고야',
#  '이대로가면서현의차투자증여린내가 채권 매긴다',
#  '이를준준 계약…한수 끝에준코비로',
#  '스웨덴 ,부 ·차관교체요청에브라中,부패한·범 다시만나자',
#  '이런데株 시는나…檢에서·서· 서·사 ·총 ·총·억억 증표·합',
#  '"제가는축제1년만원하동한 겨축',
#  '이는채 리젠지몇년이리빼고 소폭 하',
#  '이번학기에혁이본 제가능한번면예.두분의명 한야',
#  '작은 시·도민 만족을 위한시·도민의의위',
#  '카도서다로야 도보 본다',
#  '[반기준국내방송]글쓴색 위에서본의 이',
#  '"스코트렉시폰트 모 [UNK]"로 방음되 공[UNK]',
#  '더플 앱스쿨어애플뮤직 월넛터원플립제 원',
#  '아웃렛도할인 아웃렛…재고상품은울린류 의일종',
#  '눈은커녕여도 눈은 못 속인다청의 진물물',
#  '이어간김상선박사 한상석 교우은얼어 강',
#  '[단독][ [설주의가는……]부터]]시·예비계·종합',
#  '김무성,유승민, 유승민,유승민,국회 역설…임석·동·院 ·성 병행·합',
#  '문재인대통령은교당국당쓰다졌다소식듣고 문대통령에게로 건',
#  '그는웨딩  가웨 외로워때은웨해눈',
#  '[이미지영역][[[[[[[[풀HD 해상도적으로…스마트기기중에서세 최고',
#  '미국의금융팩트럼블반도스윗비업 네온크 흡수병',
#  '서울은월·토지상·시작…올까페북·도로 상·끝조천원 풀린다',
#  '北,평통위에대한원,집단탈북에 즉해괴사문서내라요구',
#  '프로듀이다테언 차에부진 이메이동료수이',
#  '게일판 대민소인싸상 수상 축하 라 .',
#  '이번출자린행동행성공단 경협사업금번신청접신작은',
#  '특징적성소 성적전망강',
#  '자본이고간의몇년전우리스벅 떻게읽어',
#  "''성에일리 쇼쿠쿠아마야 알렉사 앱도니가 인기",
#  '트뤼트뤼시트 [UNK]…英 ----공정한번합이 안 되면안되지야',
#  '與 野,국민을 위에는 小위에 여야 ,국민 사만 참여해야',
#  '나는치의치다치루마니아 방문…정 회에 함 기도',
#  '그는라엘 네버틀러  총리의일의일을 겨냥한 작은라엘행',
#  '-로체스터의부는1위위 성남 고위선두추격잰걸음',
#  '한국은고속인프라넷 가입률이…위…기… 가입자는고속만',
#  '美,‘웨슬리’제재로 ‘‘‘ ‘‘망 구축’‘질 ’’까종합',
#  'KTX부선 천안~청주공장천년전철화 본격 추진…년전공',
#  '삼성 미육군기술육성사된대 한국공- 공-교-팀별선정',
#  '···········접은 평창의림 준비 착',
#  "日자민당' 로'헌법'조는'세개의유산…'정 바에귀만은안",
#  '말로하는 대화형인싸 내비 나왔다…구출시종료',
#  '-승우,伊,로나로 완, 이,….- 계약',
#  '경찰은 야 .니 합인고철회소...진술한건유족유수예씨',
#  '美 ,北수란 전대통령,제재받은날이날발배제 소문 흉',
#  '민주 민생· 여야 ,국민의당월국회,국민의국민설득·박순',
#  '현정부,선유건양실업손실실업억원적 지종합',
#  '한국아이돌라이프러개월만원운 돌라이…에그이트',
#  '한국기술원 -투 -원 상용화 준비…한국의 기술 코어 장비에 연동 검증',
#  '문은계블락스윗트 술인데우리 녀지[UNK]',
#  '애플,구글-러와 제휴한알뜰스에 아이폰6.5G-5 공급…아이폰가좋아원',
#  '이는성적점멸모비스 연륜 질주종목',
#  '美부통령이보미국무부토론서도북핵 ·미사일 이슈로…美펜스펜스 불바다공방',
#  '北,北,北도도발 가능성에대한주시…세계의 상·위 개최전망',
#  "'삼바 '울산에라스를꺾어닝.나는눈.…이먼 .",
#  '남북이정미담담 만찬으로 향하는 남북의상',
#  '이산문의자린관가문산가 가 기획',
#  '서울마포구 신림포포합정보존폐신설….정보서비스등 제공',
#  '위클링 스윗글 전성시대 맞은해외방문뜩 .그램',
#  '서해상운교란 사흘째(중·서·서·서도조업·어업·선운항 ).',
#  '경희희 원상담도희…카불에메신향 봇 도',
#  '朴대통령의령군,식,산 ,호 통한 창조경제생보, 구종합',
#  '해 넘긴 장기 파업에서대전출출전 결퇴',
#  '어교어는 어~이',
#  '( )- 싱크탱 -노엘피브렉시트 시간방법족',
#  '이적금이십년금불[UNK]인다….입고간 례해 리용',
#  '이는국국콩가루만·하·입…하· 입….사소통 사소통  프닝',
#  '봄꽃이글램세종[UNK]',
#  '북진 ,구,표팀,리,오픈 ,운영을위해 ,남',
#  '美이일북 본사 美사장 방한…한국에일리야페북대란 입장 설명안할듯',
#  '삼성전, 갤노트3G3에서밋中소비',
#  '중국의정상-사협치포함 -력한 -합억-력한-[UNK]…中역할 중에-합',
#  '청춘의창단 하나의',
#  '(시에 그후성미에장에에스트골라 구에',
#  '갤리테일·신형 ·메탈·메탈·메탈 내달 ·일 동시출시시 유력…가는만원',
#  '이를더러이 속도평가 보고서를놓고 뢰성 재',
#  '이는비동맹의서 호에무즈참아휴',
#  '대저는또한번째진자초딩 자와 은또학년 전가',
#  '시는아 내 시는아 상공서 무인도에대한격이돼',
#  '이는득득천만원득도득리 월세는출진다',
#  '아시안게임에페흥민결식성한국 키키스에키 승지',
#  '갤5월욜연휴 첫주 만천대개…흥행은어갈까',
#  '이는컵 훈련을 찾은후독은 기( [UNK])는컵은국팀에서(심 )는',
#  '‘···‘ 비 ’고‘비’도잠시후는·근…소나기는 찔끔',
#  '온오프인개학 두번원수 테다',
#  '서울에오는 에강풍의보…저녁부터 ',
#  '선관은 일일일국 첫번정책회 개',
#  '北 ,정·관계신년에너지리젠제강[UNK]설산·산…력제 급종',
#  "이어간이'의욕'로인해,한명이사진…희생이…이부분은린이",
#  '동,천,동,서양양,동 구간 양,방,동,천일 재난,동 ,천간재난,단',
#  '자,시장활성화특화룡포엄포축사하는해찬호대표',
#  '금을금의금국경제벌 요래딩댕에 흔들어',
#  '이를케니딩스주주법인수병',
#  '이백년도,국,국,권,어,이 백년  시상',
#  '중국은 이르면 중국에 레폰 은가세환',
#  '삼성,이노텍,LG,삼성 호봉이 …면…지…대…업 ……인사가…….',
#  '소사의탈수훈 봉승 훈승',
#  '국민과의‘대정부의당·통령·최저임대인상·의정부 축가할 길',
#  '송철호 울산의장님발언경청하는 현미밥',
#  '아시안게임에(극전사)의(승리)에대한 외침이다',
#  '그는 방에그르포안과에자에안에논',
#  '(부제는제작은제개사 는제 의무는제개는제',
#  '인천하는 .당은대단',
#  '이독 작년 세다시는파트타임분양권만은…는 투',
#  '朴대통합일베댓국민의테베방지법과킨다는지',
#  '금융당국 ,초부채증폭…금융위 금투·융자종합검토안은정해',
#  '인제 자작나무의 숲 입산통제제가일개간',
#  '北,통령…김정은,연내에방 가능성 열려있다…의방결에 달해',
#  '이는이크메니스 총리에게국협력하.',
#  ' 두산 김현수 두산김현수( 이상두산수)인 투-포',
#  '메리츠종금 내년 코스피 ,내년3월∼2월∼코스피 등락',
#  '이들판 과기통부동촌락스벅고 여름에캠프 개',
#  "'에나 드라- 재-정--재-정강조-통--책 보완위해 필독",
#  '은행연장은 첫 사는 편에는내년는지는첫사 사료.',
#  '북한과 군, 외교,외교,그리고우래다유력한일일대특',
#  '오늘의일호엔씨제이감독 김현수가돌이오려면 좀 더 기를야',
#  '(자기의르다르객)',
#  "'얀마'는자신을사한일해야사태 내거부",
#  '北,김호 외무상 기용…김정은새 외통린치룬미협에 나서겠다',
#  '[[[일년이면무료[공지능]]건강·흡연률 상담',
#  "러 日과'영토'쟁론도카이리젠지 련·련…련·보항…",
#  '미·러,남중국해갈등 속 프랑스서핵미사일 발사 훈령은이례공',
#  '제세회의한다발레축고 파팅',
#  '이글의기 문신 이문화이자필필일기 역본출출',
#  "이밖에' 기업형기업'대주택' '대주택 '설·설비스포츠담용",
#  '화산이코마에일리화산에재가천ｍ에 솟아',
#  "염·설 · 기업·'존케리 총리 '란 '에 '락 차단해",
#  '美,선 ·후배토론거부판정… 힐·리,더두터운층에브리짓할까?초·빙 판세 변주·빙목판세.',
#  '(재링스톰시아(쌍포)(칼텍)(사각 )(삼각)()합',
#  '경춘궁춘 하루이틀만에 초미세먼지 의보 해 종합',
#  "'재장'대', '굴 두꺼운','자',반성없이 내탓",
#  '깜깜이,옵트뤼테테앤……국외로행로행제 가 마련',
#  '속보 =희· 고·은 중희·기·고· 모를 본다…-회로 줄고면의작용',
#  '다시말해 여행은제수맥어글리터닝 지친마음 풀어놓을 링 코스',
#  '이들픽날씨낮은 강릉 도대도 도도먼지 호',
#  '서울양재동페인트공업 본사와 연결된영업계륵.억원…',
#  '코와닥스벅일레븐 드랍스터천만원 규모 조',
#  "'삼십사년'농구·여자배구 일본에쓰훈수취소",
#  '"현철이다.전에고.치에.연.석..로...납..바. ..',
#  '민주,민주,민주, 초야, 협치 첫발….반도 ,화도,정 ,정',
#  "김진표,'정청 '의'더 '밀해'…불협'음''음'움",
#  '((주·주·주·주·오·쿠· 치··보·불법 보관하는))쭐종합·보',
#  '수림문에는 짠하고 아린다 시 청춘의센터',
#  '이이차의티리포비어 외관은이미 개',
#  '[단독인터뷰]이글쓴사람·사회와 핵·미사일·미사일의새로운 상해',
#  '책을빌리기 쉬워진……종시 공도서관 같은곳자곳 공동 활용',
#  "'라쿠쿠'리를밟은밍스경추추전정지 중징계",
#  '명말청에 기림산국사는다들은에아남가',
#  '故은경 ,울린넨도대표 악기 기증',
#  "'이도아,코·코·과이 ·화·코·이·부…옳은것은 서달'",
#  '충북교육청 노군조합은소당소동군별 양한 목소군과용',
#  '롯데에브리디론트에리벤투 승두에드블럼은연',
#  '한파 뚫고서울서아프리카…포틀랜드몬고앱스게임게임 출출위경기종합',
#  '이는공지2016년 초 한번째 비스',
#  '그래픽은분기서아프리카인구만천명 순출',
#  '노동절은한낮초.름 더.[UNK]미세한밤·오존·비.',
#  '(성 갤노트)으. 다.그중에잇템이든다아이폰과맞결',
#  '靑 민생·국권대통, 사면·뇌물수수사범 불충· 원·청훨씬 화·화·보',
#  '삼성, 오는삼성,삼성, 새스마트폰버전 공개…삼성-로폰업무,효율 높여',
#  '美,이끈, 美,그의작 기후위기 ,[UNK]…켓의수는 실패',
#  '한해동안,유씨네년 연결 영업익이년억이년억감소',
#  '미국서기브린스윗심 집지달 [UNK] 광조 위',
#  '맨유의욕그바 스윗유상…천원천원이 쓰려졌다',
#  '에브리아쥬리성엘에스티에서니니규 니',
#  '신세계푸어스 ,분기,영,익 ,오억원…신세계푸,신세계푸',
#  '올해는이슈터 ,분기별영,이익은이,억원…흑자,환종합',
#  '지난해말 화곡동에서사동동 상오동장시민들견반영 복구',
#  '-미정상회담,그대에게일선턱밑',
#  '계도되는 유가의승우-월 -월-건 -건몇개월 만에 최악',
#  "러,러스파이들 연루 前대통령,프캠프 고문으로'원 보궐선택'도",
#  '朴대통령통령 ···절 기·사 북·정기···의·행 강· 행망',
#  '경북구·경북 구름이많은 날씨…낮에온 (·∼·)도',
#  '美 휴렛턴스쇼핑몰서총격',
#  '아,안게임,박지은,나도농동 ,일팀이,할 ,….부 ,하,',
#  '[한겨레]월간지십만명초인종알고보니 美커 괴힘',
#  '-로케구라-러리캡 위에그국의에 금 은천은금',
#  '넥과 브리검치코는몇년 연속 지',
#  '이는총 은총수의 검수와 금융재산한 방 금,가,분 ,각,합',
#  '저임당만원 약 행[UNK]',
#  "'노엘리' 출시'' …럭스벅출출리' 출시'금 올라",
#  '그는그를 품에안에팜한닻 올렸다',
#  '코브라보톡스기관인벤매수의 반으로…스 0대 상승의합',
#  '책은자스민우작 비어려면 맛맞아요죠',
#  '카페에브리아벤통신보안에에다른 네워 에',
#  '대·충남,이·영 강으로…가는로…가지고 …판이어져',
#  '코로나는단감 이지는고속도 가·성이 려[UNK]',
#  ' 당대표 김정은의당 결산보고내',
#  '미국정부는리론 금리를내는리론금리타겟비중월새 급증',
#  '국민의대표자인의당최용철대위장아는철대위장맡아',
#  '내가는정현 대마…더민, 나는경쟁에도 변로 .',
#  '부산항에 입항부산항만경항항',
#  '[뉴스1 ]법원을 기억하시나요…대망정녕녕사진전',
#  '부경우역 청- 단기,단기,단기,모집, 수,수로몰려',
#  '이를보고이우우 림 세우음으로 바라보기',
#  '이를놓고조국 퇴국국개 향방은국 개 토론',
#  "''''' 셀트'' 코'피'''''입 시 '천''''' '입",
#  '류현은현현 첫 올 시즌에는이팀서 두 번째 팀 선발투를했다',
#  '구글,유럽서베이진단은 의사를믿지 못한다….단 보조자역할',
#  '독이는리 활은원지니다',
#  "'성 베'남은 갤리젠지엔씨엔개…중·가폰으론 동남아 공",
#  '하니가자홍콩 아싸 경리스크 부',
#  '공인인이라는것은 카카페이팔서든다',
#  "' 꽁치잡' 은중조업의류…의양어획경쟁 망",
#  '여든구 박혜경정애그나째수상… 위기',
#  '자동대차는2인승 ,는2,리세이브 출시…천원,은,대, 시작',
#  '그는그린스홀리젠스홀년리요서트리…세리리리[UNK]',
#  '채널A급인사서 검수검착 의혹기검 결정',
#  '그,난 지금바에서는두번째리젠,……두명이모여 정권이진 요구종합',
#  '한국에는 세계 최초로 가입자만 명 돌파',
#  '中 홍군시위 격화.무혐한입먹는국등은먹',
#  'SKSK텔레콤은기덕아웃카운슬링이면 마트정 끝',
#  '서훈남 연일,[UNK]은 바짝 말라….사는현,내탓',
#  '北,정· 청동, ‘원혼’에대…北, 당대회 폐회합',
#  '-카·합성영 은 성·성·벌에만적용 안돼…보완책 시급',
#  '퇴락 후 ·생··막·취· ·패 후 전·위··설후 날· ··.',
#  '게니판에대살구찌는까지로 제',
#  '나도픽 감나네…앞치마 쳐진짜속㎞봅쇼레이',
#  '충북교육청운나는는…유치 포춘성은입학 소',
#  '한국선수권 재영훈수의적잘못 인정…협회가프로행보진짜렸다',
#  "'가다르항공의서든항권리할 판",
#  '푸에 비인기빛낸 성공의 디네',
#  '그는한지다하다하미 싱송이터널시',
#  '이는류 시에어케니자,건호 회장 수원에산 잠들다',
#  '삼년물이는분기 업이익억세번년다늘어',
#  '((수)천안시의경우)천안의장님마님언균주.전 완.해야',
#  '이를(를 )말기.에 대해',
#  ...]

# %%
Noise_text_data["text"] = processed_data
# Out:
# /tmp/ipykernel_365291/2175804111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Noise_text_data["text"] = processed_data

# %%
Noise_text_data
# Out:
#                        ID                                 text  target
# 0     ynat-v1_train_00000               정씨리파 미사 미사 이용기간 단품 분종보       4
# 1     ynat-v1_train_00001                 '찰라국의라국 로한길다 회장  라국송       3
# 2     ynat-v1_train_00002              - 김정숙 자주통일 새정치는이제열은나가야보       2
# 4     ynat-v1_train_00004  오바마,美대선을앞두고 오바마,오바마,단 발오바마에비해 감시 강화       6
# 6     ynat-v1_train_00006                프로야구‘롯지덕구)’광주 경기구장천취소       1
# ...                   ...                                  ...     ...
# 2786  ynat-v1_train_02786                      텅 빈 채실 선생님은홀로터리       3
# 2787  ynat-v1_train_02787           이는이 노바 라이어패·미어패 어패· 결상품 상품       6
# 2788  ynat-v1_train_02788                  남원소식 춘제가학단장[UNK] 모집       0
# 2792  ynat-v1_train_02792                       높은박애율…선수 몸값 상승       1
# 2797  ynat-v1_train_02797           텔레그램,한밤 등亞서 시간다운…버정[UNK]종보       4
#
# [1285 rows x 3 columns]

# %%
Noise_text_data.to_csv(os.path.join(data_path,"train_Noise_fillmask_data.csv"), encoding="utf-8-sig")
